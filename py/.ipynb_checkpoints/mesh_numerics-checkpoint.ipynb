# %%
import os, io, cProfile, pstats, pickle, shutil
import pymeshlab
import sys
import igl
import meshplot as plot
import pickle
from init_cm_data import *
from conformal_impl.optimization import *
#from conformal_impl.layout import *
from optimization_py import *
from scipy.sparse import csr_matrix
#from conformal_impl.finite_diff import *
#import conformal_impl.functions_with_jacobians as FWJ
#import script_conformal
from conformal_py import *
from conformal_impl.meshgen import *
from analysis import *
# %load_ext autoreload
# %autoreload 2
from IPython.core.display import HTML, clear_output

# %% [markdown]
# # Hemispheres

# %% [markdown]
# ## Generate Hemispheres

# %%
# Create hemispheres
data_dir = '../data/hemispheres_isotropic'
os.makedirs(data_dir, exist_ok=True)
for n in (1 + np.arange(0,20)):
    print("Creating mesh of height {}".format(n))
    # Create hemisphere of height n froma n implicit surface
    ms = pymeshlab.MeshSet()
    expr='x*x + y*y + z*z/' + str(n*n) + ' - 0.5'
    ms.implicit_surface(minz=0,maxz=2*n,expr=expr)
    ms.simplification_edge_collapse_for_marching_cube_meshes()
    ms.remeshing_isotropic_explicit_remeshing()
    #ms.merge_close_vertices()

    # Save file as obj
    m='hemisphere_'+str(n)
    output_path = os.path.join(data_dir,m+'.obj')
    ms.save_current_mesh(output_path)
# Out:
# Creating mesh of height 1
# Creating mesh of height 2
# Creating mesh of height 3
# Creating mesh of height 4
# Creating mesh of height 5
# Creating mesh of height 6
# Creating mesh of height 7
# Creating mesh of height 8
# Creating mesh of height 9
# Creating mesh of height 10
# Creating mesh of height 11
# Creating mesh of height 12
# Creating mesh of height 13
# Creating mesh of height 14
# Creating mesh of height 15
# Creating mesh of height 16
# Creating mesh of height 17
# Creating mesh of height 18
# Creating mesh of height 19
# Creating mesh of height 20

# %%
# View mesh
n = 20
m = 'hemisphere_'+str(n)
v, f = igl.read_triangle_mesh(data_dir+'/'+m+'.obj')
plot.plot(v,f, shading={'wireframe': True})
# Out:
# Renderer(camera=PerspectiveCamera(children=(DirectionalLight(color='white', intensity=0.6, position=(0.0001055…

# %% [markdown]
# ## Hemisphere Mesh Tests

# %%
# Run conformal and optimization method on hemisphere meshes
data_dir = '../data/hemispheres_isotropic'
for n in (1 + np.arange(20)):
    m='hemisphere_'+str(n)
    output_dir = '../output/hemispheres_isotropic/'+m
    os.makedirs(output_dir, exist_ok=True)

    # Initialize mesh from the data set with flat target angles
    v, f = igl.read_triangle_mesh(data_dir+'/'+m+'.obj')
    Th_hat = map_to_disk(v,f)
    free_angles = True
    C, vtx_reindex = fv_to_double(v, f, Th_hat, free_angles)

    # Get initial (and target) lambdas
    lambdas_target = lambdas_from_mesh(C)
    lambdas_init = lambdas_from_mesh(C)
    
    # Run optimization code with 0 iterations (should be the same as conformal)
    proj_params = ProjectionParameters()
    proj_params.do_reduction = True
    opt_params = {}
    opt_params['num_iter'] = 0
    _, lambdas = optimize_lambdas(C,
                                  lambdas_init,
                                  lambdas_target,
                                  proj_params=proj_params,
                                  opt_params=opt_params)

    # Save output lambdas and overlay mesh viewers to file    
    vw_mesh, vw_layout = generate_overlay_viewer(C, lambdas, v, f, Th_hat)
    np.savetxt(os.path.join(output_dir, 'conf_lambdas'), lambdas)
    vw_mesh.save(os.path.join(output_dir, 'conf_mesh'))
    vw_layout.save(os.path.join(output_dir, 'conf_layout'))
    
    # Run optimization code with 1000 iterations
    opt_params['min_ratio'] = 0.15
    opt_params['num_iter'] = 100
    opt_params['max_angle'] = 100
    opt_params['max_grad_range'] = 10
    _, lambdas = optimize_lambdas(C,
                                  lambdas_init,
                                  lambdas_target,
                                  proj_params=proj_params,
                                  opt_params=opt_params)

    # Save output lambdas and overlay mesh viewers to file    
    vw_mesh, vw_layout = generate_overlay_viewer(C, lambdas, v, f, Th_hat)
    np.savetxt(os.path.join(output_dir, 'opt_lambdas'), lambdas)
    vw_mesh.save(os.path.join(output_dir, 'opt_mesh'))
    vw_layout.save(os.path.join(output_dir, 'opt_layout'))
# Out:
# Flips: 912
# Starting optimization
# Initial l2 energy: 0.0
# Initial optimization energy: 0.0
# Initial max angle error: 0.30806419622964576
#
# Performing initial conformal projection
# Error: 1.95399e-14
#
# First projection complete
# Flips: 917
# L2 energy before optimization: 133.85732221287878
# Optimization energy: 8958.891355001226
# Max angle error before optimization: 2.1316282072803006e-14
#
# Error: 1.95399e-14
# Flips: 917
# Angle error: 1.95399e-14
# Plot saved to file ../output/hemispheres_isotropic/hemisphere_1/conf_mesh.html.
# Plot saved to file ../output/hemispheres_isotropic/hemisphere_1/conf_layout.html.
# Flips: 912
# Starting optimization
# Initial l2 energy: 0.0
# Initial optimization energy: 0.0
# Initial max angle error: 0.30806419622964576
#
# Performing initial conformal projection
# Error: 1.95399e-14
#
# First projection complete
# Flips: 917
# L2 energy before optimization: 133.85732221287878
# Optimization energy: 8958.891355001226
# Max angle error before optimization: 2.1316282072803006e-14
#
# Iteration 0
# L2 energy at start of iteration 0: 133.85732221287878
#
# Optimization energy: 8958.891355001226
# Getting line search direction
# Flips: 917
# gk 1.3944288688895696
# Finding direction took 0.13912391662597656 s
# Delta lambdas norm 130.3115298527978 in iteration 0
#
# Line step with beta 1.0
# Flips: 2336
# Energy after line step: 30.605357331909723
# Max angle error: 0.7849267523956147
# Optimization energy: 468.3439487069401
# Max stretch relative to target: 1.1102715153913805
# Max stretch relative to initial: 1.1102715153913805
# Max stretch relative to previous: 1.2413789759591536
#
# Projecting to constraint
# Error: 2.21778e-11
# Projecting to constraint took 0.19572901725769043 s
# Range of conformal scale factors: [-0.08611485064395098, 0.07573469693038329]
# Flips: 2285
# Energy after projection: 35.89443175877885
# Optimization energy: 644.2051156428158
# Max angle error: 2.2177815139912127e-11
# Max stretch relative to target: 1.1102715153913805
# Max stretch relative to initial: 1.1102715153913805
# Max stretch relative to previous: 1.2051189389366168
#
# Total optimization time 0.6964168548583984
# Energy at end of iteration 0: 35.89443175877885
# Optimization energy: 644.2051156428158
# Max metric distortion: 5.1317281682537335
# Norm metric distortion: 58.93863928662247
# Max area distortion: 2.1658952935614377
# Norm area distortion: 21.510303870135576
# Max conformal scale: 0.7007710024568499
# Norm conformal scale: 38.65236652464169
# Full mesh energy at end of iteration 0: 49.94791081994771
# Max angle error: 2.2177815139912127e-11
# Convergence ratio at end of iteration 0: 0.973510658203352
#
#
# Iteration 1
# L2 energy at start of iteration 1: 35.89443175877885
#
# Optimization energy: 644.2051156428158
# Getting line search direction
# Flips: 2285
# gk 0.9308165995976223
# Finding direction took 0.13762712478637695 s
# Delta lambdas norm 14.225125228095303 in iteration 1
#
# Line step with beta 1.0
# Flips: 2448
# Energy after line step: 32.95536441210643
# Max angle error: 0.7163642019415768
# Optimization energy: 543.0280217673654
# Max stretch relative to target: 1.1256598503002195
# Max stretch relative to initial: 1.1256598503002195
# Max stretch relative to previous: 1.062469597257168
#
# Projecting to constraint
# Error: 3.49338e-11
# Projecting to constraint took 0.20380902290344238 s
# Range of conformal scale factors: [-0.19488241453991922, 0.015334294946494404]
# Flips: 2452
# Energy after projection: 35.58849161834437
# Optimization energy: 633.2703678344837
# Max angle error: 3.4933833603645326e-11
# Max stretch relative to target: 1.1256598503002195
# Max stretch relative to initial: 1.1256598503002195
# Max stretch relative to previous: 1.0501596256256494
#
# Total optimization time 1.2022697925567627
# Energy at end of iteration 1: 35.58849161834437
# Optimization energy: 633.2703678344837
# Max metric distortion: 3.2666993670169067
# Norm metric distortion: 57.10894082632007
# Max area distortion: 2.1245929696688943
# Norm area distortion: 23.386293749867004
# Max conformal scale: 0.2709524239796577
# Norm conformal scale: 7.230084986363493
# Full mesh energy at end of iteration 1: 49.5645918601923
# Max angle error: 3.4933833603645326e-11
# Convergence ratio at end of iteration 1: 0.3963045110643437
#
#
# Iteration 2
# L2 energy at start of iteration 2: 35.58849161834437
#
# Optimization energy: 633.2703678344837
# Getting line search direction
# Flips: 2452
# gk 0.9924228727415629
# Finding direction took 0.14499783515930176 s
# Delta lambdas norm 13.937096616681467 in iteration 2
#
# Line step with beta 1.0
# Flips: 2574
# Energy after line step: 32.74596270570744
# Max angle error: 1.0410360683597375
# Optimization energy: 536.1490367617913
# Max stretch relative to target: 1.1338247935616632
# Max stretch relative to initial: 1.1338247935616632
# Max stretch relative to previous: 1.0962764550295288
#
# Projecting to constraint
# Error: 1.0613e-09
# Projecting to constraint took 0.16843414306640625 s
# Range of conformal scale factors: [-0.22749005389712876, 0.045679955503125085]
# Flips: 2554
# Energy after projection: 37.942882120704994
# Optimization energy: 719.8311518128573
# Max angle error: 1.0612968281975554e-09
# Max stretch relative to target: 1.1336863960693573
# Max stretch relative to initial: 1.1336863960693573
# Max stretch relative to previous: 1.1380477022272257
#
# Line step with beta 0.5
# Flips: 2517
# Energy after line step: 33.47922847185396
# Max angle error: 0.40734336891527967
# Optimization energy: 560.4293695352983
# Max stretch relative to target: 1.1256380476084702
# Max stretch relative to initial: 1.1256380476084702
# Max stretch relative to previous: 1.02378622158865
#
# Projecting to constraint
# Error: 5.50671e-13
# Projecting to constraint took 0.17024993896484375 s
# Range of conformal scale factors: [-0.06955029975464595, 0.02173176172378107]
# Flips: 2521
# Energy after projection: 34.74915938534485
# Optimization energy: 603.7520389940502
# Max angle error: 5.471179065352771e-13
# Max stretch relative to target: 1.1256380476084702
# Max stretch relative to initial: 1.1256380476084702
# Max stretch relative to previous: 1.0286057995674864
#
# Total optimization time 1.89469575881958
# Energy at end of iteration 2: 34.74915938534485
# Optimization energy: 603.7520389940502
# Max metric distortion: 3.680272596475585
# Norm metric distortion: 58.08016541605038
# Max area distortion: 3.4314733116896075
# Norm area distortion: 21.011853108053646
# Max conformal scale: 0.49515085866956243
# Norm conformal scale: 7.188854014054762
# Full mesh energy at end of iteration 2: 48.34724625795531
# Max angle error: 5.471179065352771e-13
# Convergence ratio at end of iteration 2: 0.39161807603830784
#
#
# Iteration 3
# L2 energy at start of iteration 3: 34.74915938534485
#
# Optimization energy: 603.7520389940502
# Getting line search direction
# Flips: 2521
# gk 0.992338497523245
# Finding direction took 0.13774991035461426 s
# Delta lambdas norm 10.28291899789436 in iteration 3
#
# Line step with beta 1.0
# Flips: 2644
# Energy after line step: 33.19285547945936
# Max angle error: 0.13859019254042337
# Optimization energy: 550.8828274401377
# Max stretch relative to target: 1.1391582608274455
# Max stretch relative to initial: 1.1391582608274455
# Max stretch relative to previous: 1.019173983755228
#
# Projecting to constraint
# Error: 8.88178e-15
# Projecting to constraint took 0.16566109657287598 s
# Range of conformal scale factors: [-0.022989650776962165, 0.013628775422161926]
# Flips: 2638
# Energy after projection: 33.2951647219537
# Optimization energy: 554.2839969310149
# Max angle error: 1.2434497875801753e-14
# Max stretch relative to target: 1.1391582608274455
# Max stretch relative to initial: 1.1391582608274455
# Max stretch relative to previous: 1.019173983755228
#
# Total optimization time 2.328423023223877
# Energy at end of iteration 3: 33.2951647219537
# Optimization energy: 554.2839969310149
# Max metric distortion: 3.9048556951831577
# Norm metric distortion: 69.98447951159602
# Max area distortion: 1.742621297356913
# Norm area distortion: 21.1502508258974
# Max conformal scale: 0.234356530720312
# Norm conformal scale: 6.760214202991415
# Full mesh energy at end of iteration 3: 46.098923661273545
# Max angle error: 1.2434497875801753e-14
# Convergence ratio at end of iteration 3: 0.2959184964408402
#
#
# Iteration 4
# L2 energy at start of iteration 4: 33.2951647219537
#
# Optimization energy: 554.2839969310149
# Getting line search direction
# Flips: 2638
# gk 1.0432465513605802
# Finding direction took 0.1425647735595703 s
# Delta lambdas norm 3.3655004888419353 in iteration 4
#
# Line step with beta 1.0
# Flips: 2540
# Energy after line step: 33.12463434217952
# Max angle error: 0.494807496875616
# Optimization energy: 548.6207001515494
# Max stretch relative to target: 1.1441059108447207
# Max stretch relative to initial: 1.1441059108447207
# Max stretch relative to previous: 1.0263441008364906
#
# Projecting to constraint
# Error: 3.78364e-13
# Projecting to constraint took 0.16623592376708984 s
# Range of conformal scale factors: [-0.0987247436678261, 0.03603478193805298]
# Flips: 2542
# Energy after projection: 33.68724524260791
# Optimization energy: 567.4152460178045
# Max angle error: 3.836930773104541e-13
# Max stretch relative to target: 1.1441059108447207
# Max stretch relative to initial: 1.1441059108447207
# Max stretch relative to previous: 1.039004378642307
#
# Line step with beta 0.5
# Flips: 2620
# Energy after line step: 33.1673491358213
# Max angle error: 0.15454160278501128
# Optimization energy: 550.0365243487329
# Max stretch relative to target: 1.1416205683237088
# Max stretch relative to initial: 1.1416205683237088
# Max stretch relative to previous: 1.006564479016742
#
# Projecting to constraint
# Error: 8.88178e-15
# Projecting to constraint took 0.16724896430969238 s
# Range of conformal scale factors: [-0.026983585597091318, 0.007706064413967378]
# Flips: 2620
# Energy after projection: 33.27830599473656
# Optimization energy: 553.7228249396597
# Max angle error: 1.4210854715202004e-14
# Max stretch relative to target: 1.1416205683237088
# Max stretch relative to initial: 1.1416205683237088
# Max stretch relative to previous: 1.008204586117106
#
# Total optimization time 3.0006799697875977
# Energy at end of iteration 4: 33.27830599473656
# Optimization energy: 553.7228249396597
# Max metric distortion: 4.044566634682909
# Norm metric distortion: 69.0968500687002
# Max area distortion: 3.535345300471522
# Norm area distortion: 22.54698957782631
# Max conformal scale: 0.2781668066068513
# Norm conformal scale: 5.970913772092266
# Full mesh energy at end of iteration 4: 46.08585688058949
# Max angle error: 1.4210854715202004e-14
# Convergence ratio at end of iteration 4: 0.1010807580303947
#
#
# Error: 1.06581e-14
# Flips: 2620
# Angle error: 1.06581e-14
# Plot saved to file ../output/hemispheres_isotropic/hemisphere_1/opt_mesh.html.
# Plot saved to file ../output/hemispheres_isotropic/hemisphere_1/opt_layout.html.
# Flips: 890
# Starting optimization
# Initial l2 energy: 0.0
# Initial optimization energy: 0.0
# Initial max angle error: 0.3186867395570694
#
# Performing initial conformal projection
# Error: 1.77636e-14
#
# First projection complete
# Flips: 890
# L2 energy before optimization: 333.5052554429014
# Optimization energy: 55612.877704017454
# Max angle error before optimization: 1.5987211554602254e-14
#
# Error: 1.77636e-14
# Flips: 890
# Angle error: 1.77636e-14
# Plot saved to file ../output/hemispheres_isotropic/hemisphere_2/conf_mesh.html.
# Plot saved to file ../output/hemispheres_isotropic/hemisphere_2/conf_layout.html.
# Flips: 890
# Starting optimization
# Initial l2 energy: 0.0
# Initial optimization energy: 0.0
# Initial max angle error: 0.3186867395570694
#
# Performing initial conformal projection
# Error: 1.77636e-14
#
# First projection complete
# Flips: 890
# L2 energy before optimization: 333.5052554429014
# Optimization energy: 55612.877704017454
# Max angle error before optimization: 1.5987211554602254e-14
#
# Iteration 0
# L2 energy at start of iteration 0: 333.5052554429014
#
# Optimization energy: 55612.877704017454
# Getting line search direction
# Flips: 890
# gk 3.626146315805757
# Finding direction took 0.20506811141967773 s
# Delta lambdas norm 326.73274619484584 in iteration 0
#
# Line step with beta 1.0
# Flips: 7447
# Energy after line step: 66.86903597109058
# Max angle error: 1.7262117655753553
# Optimization energy: 2235.733985851503
# Max stretch relative to target: 1.2425218994923226
# Max stretch relative to initial: 1.2425218994923226
# Max stretch relative to previous: 2.983321939032962
#
# Projecting to constraint
# Error: 8.88178e-15
# Projecting to constraint took 0.2922029495239258 s
# Range of conformal scale factors: [-0.2967610975664537, 0.16543904684633212]
# Flips: 7259
# Energy after projection: 95.70126444444736
# Optimization energy: 4579.366008133023
# Max angle error: 1.4210854715202004e-14
# Max stretch relative to target: 1.2455043184047079
# Max stretch relative to initial: 1.2455043184047079
# Max stretch relative to previous: 2.3933766823202056
#
# Total optimization time 0.9840679168701172
# Energy at end of iteration 0: 95.70126444444736
# Optimization energy: 4579.366008133023
# Max metric distortion: 17.245373242546716
# Norm metric distortion: 250.84651558410334
# Max area distortion: 74.43201054435102
# Norm area distortion: 198.62835937261497
# Max conformal scale: 1.8149258143434674
# Norm conformal scale: 96.29376920869558
# Full mesh energy at end of iteration 0: 134.71018175074366
# Max angle error: 1.4210854715202004e-14
# Convergence ratio at end of iteration 0: 0.9796929459505472
#
#
# Iteration 1
# L2 energy at start of iteration 1: 95.70126444444736
#
# Optimization energy: 4579.366008133023
# Getting line search direction
# Flips: 7259
# gk 1.374245459554725
# Finding direction took 0.23432111740112305 s
# Delta lambdas norm 54.55490015362531 in iteration 1
#
# Line step with beta 1.0
# Flips: 8938
# Energy after line step: 78.62884257421247
# Max angle error: 1.8625748589024997
# Optimization energy: 3091.247442280144
# Max stretch relative to target: 1.5274102527032132
# Max stretch relative to initial: 1.5274102527032132
# Max stretch relative to previous: 1.3290130011733392
#
# Projecting to constraint
# Error: 8.88178e-15
# Projecting to constraint took 0.37909507751464844 s
# Range of conformal scale factors: [-0.5742921683461069, 0.10132882067931351]
# Flips: 8851
# Energy after projection: 98.52759067958189
# Optimization energy: 4853.8430625616165
# Max angle error: 1.4210854715202004e-14
# Max stretch relative to target: 1.5274102527032132
# Max stretch relative to initial: 1.5274102527032132
# Max stretch relative to previous: 1.3195409653810886
#
# Line step with beta 0.5
# Flips: 8375
# Energy after line step: 83.22592245040099
# Max angle error: 0.6652051057492354
# Optimization energy: 3463.2770838600795
# Max stretch relative to target: 1.3331102634199026
# Max stretch relative to initial: 1.3331102634199026
# Max stretch relative to previous: 1.079123023842356
#
# Projecting to constraint
# Error: 1.3415e-11
# Projecting to constraint took 0.2777700424194336 s
# Range of conformal scale factors: [-0.17342226318740656, 0.039055184845441605]
# Flips: 8376
# Energy after projection: 89.67357285635914
# Optimization energy: 4020.6748344123757
# Max angle error: 1.3420375921668892e-11
# Max stretch relative to target: 1.3331102634199026
# Max stretch relative to initial: 1.3331102634199026
# Max stretch relative to previous: 1.0590494637386025
#
# Total optimization time 2.1520299911499023
# Energy at end of iteration 1: 89.67357285635914
# Optimization energy: 4020.6748344123757
# Max metric distortion: 15.532961189043984
# Norm metric distortion: 243.20482754820844
# Max area distortion: 15.5733403317926
# Norm area distortion: 93.97865671675183
# Max conformal scale: 0.44889331361715384
# Norm conformal scale: 21.50836841961592
# Full mesh energy at end of iteration 1: 126.17174452659617
# Max angle error: 1.3420375921668892e-11
# Convergence ratio at end of iteration 1: 0.5700541207090667
#
#
# Iteration 2
# L2 energy at start of iteration 2: 89.67357285635914
#
# Optimization energy: 4020.6748344123757
# Getting line search direction
# Flips: 8376
# gk 1.5902249506778494
# Finding direction took 0.23477816581726074 s
# Delta lambdas norm 42.39691967765734 in iteration 2
#
# Line step with beta 1.0
# Flips: 9769
# Energy after line step: 79.01804142007795
# Max angle error: 1.6678195946770327
# Optimization energy: 3121.9254349325774
# Max stretch relative to target: 1.5663279624480497
# Max stretch relative to initial: 1.5663279624480497
# Max stretch relative to previous: 1.1475417093732425
#
# Projecting to constraint
# Error: 7.10543e-15
# Projecting to constraint took 0.29167890548706055 s
# Range of conformal scale factors: [-0.35439692561244274, 0.14441066669744426]
# Flips: 9723
# Energy after projection: 89.41847156697425
# Optimization energy: 3997.831528686891
# Max angle error: 1.4210854715202004e-14
# Max stretch relative to target: 1.5501177305394525
# Max stretch relative to initial: 1.5501177305394525
# Max stretch relative to previous: 1.165214343086136
#
# Total optimization time 2.8579959869384766
# Energy at end of iteration 2: 89.41847156697425
# Optimization energy: 3997.831528686891
# Max metric distortion: 57.766081696689604
# Norm metric distortion: 397.4924913092034
# Max area distortion: 435.674469573705
# Norm area distortion: 764.1298726774423
# Max conformal scale: 0.5458620483822537
# Norm conformal scale: 19.160514230666784
# Full mesh energy at end of iteration 2: 125.60480636984279
# Max angle error: 1.4210854715202004e-14
# Convergence ratio at end of iteration 2: 0.472791685746363
#
#
# Iteration 3
# L2 energy at start of iteration 3: 89.41847156697425
#
# Optimization energy: 3997.831528686891
# Getting line search direction
# Flips: 9723
# gk 2.0119292006287806
# Finding direction took 0.2437591552734375 s
# Delta lambdas norm 47.27277593212534 in iteration 3
#
# Line step with beta 1.0
# Flips: 9275
# Energy after line step: 75.90090719367264
# Max angle error: 3.411118494711026
# Optimization energy: 2880.4738564112536
# Max stretch relative to target: 1.5431208000842465
# Max stretch relative to initial: 1.5431208000842465
# Max stretch relative to previous: 1.6526184426040573
#
# Projecting to constraint
# Error: 1.37142e-09
# Projecting to constraint took 0.34575676918029785 s
# Range of conformal scale factors: [-1.1317426477365566, 0.1720844062018569]
# Flips: 9211
# Energy after projection: 162.61661344377316
# Optimization energy: 13222.081483960774
# Max angle error: 1.3714220870042482e-09
# Max stretch relative to target: 1.5431208000842465
# Max stretch relative to initial: 1.5431208000842465
# Max stretch relative to previous: 2.03264392297993
#
# Line step with beta 0.5
# Flips: 9462
# Energy after line step: 79.49607882792655
# Max angle error: 1.3552032003140617
# Optimization energy: 3159.813274507956
# Max stretch relative to target: 1.415877269659303
# Max stretch relative to initial: 1.415877269659303
# Max stretch relative to previous: 1.151654992305434
#
# Projecting to constraint
# Error: 7.10543e-15
# Projecting to constraint took 0.3586618900299072 s
# Range of conformal scale factors: [-0.3777187562033304, 0.07225210377152343]
# Flips: 9476
# Energy after projection: 99.20863167450966
# Optimization energy: 4921.176299364261
# Max angle error: 1.5987211554602254e-14
# Max stretch relative to target: 1.415877269659303
# Max stretch relative to initial: 1.415877269659303
# Max stretch relative to previous: 1.1827978134061672
#
# Line step with beta 0.25
# Flips: 9790
# Energy after line step: 83.7733555145924
# Max angle error: 0.5891223727504666
# Optimization energy: 3508.987547087144
# Max stretch relative to target: 1.3596302286135837
# Max stretch relative to initial: 1.3596302286135837
# Max stretch relative to previous: 1.0372210449815973
#
# Projecting to constraint
# Error: 4.76064e-12
# Projecting to constraint took 0.2854948043823242 s
# Range of conformal scale factors: [-0.10599808182879217, 0.028181978721582502]
# Flips: 9792
# Energy after projection: 87.88875061489654
# Optimization energy: 3862.2162423237382
# Max angle error: 4.765965400110872e-12
# Max stretch relative to target: 1.3596302286135837
# Max stretch relative to initial: 1.3596302286135837
# Max stretch relative to previous: 1.0383360747140824
#
# Total optimization time 4.482142925262451
# Energy at end of iteration 3: 87.88875061489654
# Optimization energy: 3862.2162423237382
# Max metric distortion: 18.135737077330422
# Norm metric distortion: 267.87063752122225
# Max area distortion: 15.145778238045123
# Norm area distortion: 103.35200921713252
# Max conformal scale: 0.530311066072044
# Norm conformal scale: 18.06961894665017
# Full mesh energy at end of iteration 3: 123.61882117543861
# Max angle error: 4.765965400110872e-12
# Convergence ratio at end of iteration 3: 0.5286690222245426
#
#
# Iteration 4
# L2 energy at start of iteration 4: 87.88875061489654
#
# Optimization energy: 3862.2162423237382
# Getting line search direction
# Flips: 9792
# gk 1.6490718461636362
# Finding direction took 0.25145602226257324 s
# Delta lambdas norm 38.36101857019058 in iteration 4
#
# Line step with beta 0.5
# Flips: 10282
# Energy after line step: 81.36803226825103
# Max angle error: 0.6149047271415462
# Optimization energy: 3310.3783376035703
# Max stretch relative to target: 1.4782639710476346
# Max stretch relative to initial: 1.4782639710476346
# Max stretch relative to previous: 1.050745116712443
#
# Projecting to constraint
# Error: 2.61906e-11
# Projecting to constraint took 0.28734588623046875 s
# Range of conformal scale factors: [-0.14238777944143527, 0.03575139042163328]
# Flips: 10275
# Energy after projection: 83.34559881887735
# Optimization energy: 3473.2444212386245
# Max angle error: 2.6190605240117293e-11
# Max stretch relative to target: 1.4782639710476346
# Max stretch relative to initial: 1.4782639710476346
# Max stretch relative to previous: 1.043019790969345
#
# Total optimization time 5.207237005233765
# Energy at end of iteration 4: 83.34559881887735
# Optimization energy: 3473.2444212386245
# Max metric distortion: 31.609362875026655
# Norm metric distortion: 324.58963806673586
# Max area distortion: 19.934672446375192
# Norm area distortion: 114.9236535278119
# Max conformal scale: 0.4049292382540021
# Norm conformal scale: 17.89421388404766
# Full mesh energy at end of iteration 4: 117.07010193863135
# Max angle error: 2.6190605240117293e-11
# Convergence ratio at end of iteration 4: 0.43647245297953585
#
#
# Iteration 5
# L2 energy at start of iteration 5: 83.34559881887735
#
# Optimization energy: 3473.2444212386245
# Getting line search direction
# Flips: 10275
# gk 1.8854465440536776
# Finding direction took 0.25992894172668457 s
# Delta lambdas norm 26.64260093224742 in iteration 5
#
# Line step with beta 1.0
# Flips: 10408
# Energy after line step: 78.97253102681785
# Max angle error: 2.0135044702330447
# Optimization energy: 3118.330328390854
# Max stretch relative to target: 1.6161924376587329
# Max stretch relative to initial: 1.6161924376587329
# Max stretch relative to previous: 1.1768493601152248
#
# Projecting to constraint
# Error: 1.59872e-14
# Projecting to constraint took 0.3253209590911865 s
# Range of conformal scale factors: [-0.3681938456969429, 0.16295131143942487]
# Flips: 10395
# Energy after projection: 84.60319878237293
# Optimization energy: 3578.850622104854
# Max angle error: 2.1316282072803006e-14
# Max stretch relative to target: 1.6422756588997527
# Max stretch relative to initial: 1.6422756588997527
# Max stretch relative to previous: 1.1802811285788493
#
# Line step with beta 0.5
# Flips: 10396
# Energy after line step: 80.08818704104075
# Max angle error: 0.5542242543213476
# Optimization energy: 3207.058851760364
# Max stretch relative to target: 1.3836574191061826
# Max stretch relative to initial: 1.3836574191061826
# Max stretch relative to previous: 1.0432759366809974
#
# Projecting to constraint
# Error: 2.6148e-12
# Projecting to constraint took 0.29094910621643066 s
# Range of conformal scale factors: [-0.10140534681633993, 0.06982816882706076]
# Flips: 10393
# Energy after projection: 81.95604206875701
# Optimization energy: 3358.396415787935
# Max angle error: 2.609468197078968e-12
# Max stretch relative to target: 1.3881509653139346
# Max stretch relative to initial: 1.3881509653139346
# Max stretch relative to previous: 1.0426226213299803
#
# Total optimization time 6.371300935745239
# Energy at end of iteration 5: 81.95604206875701
# Optimization energy: 3358.396415787935
# Max metric distortion: 21.243201145529554
# Norm metric distortion: 345.64384868957444
# Max area distortion: 22.44003623438366
# Norm area distortion: 129.6235468967101
# Max conformal scale: 0.4504197587012114
# Norm conformal scale: 15.845013426840941
# Full mesh energy at end of iteration 5: 115.03679125739589
# Max angle error: 2.609468197078968e-12
# Convergence ratio at end of iteration 5: 0.31966416115319823
#
#
# Iteration 6
# L2 energy at start of iteration 6: 81.95604206875701
#
# Optimization energy: 3358.396415787935
# Getting line search direction
# Flips: 10393
# gk 1.709630662998049
# Finding direction took 0.25696897506713867 s
# Delta lambdas norm 22.328432222477897 in iteration 6
#
# Line step with beta 1.0
# Flips: 10610
# Energy after line step: 78.85577940135502
# Max angle error: 1.224143225889641
# Optimization energy: 3109.1169724975834
# Max stretch relative to target: 1.7207692932710663
# Max stretch relative to initial: 1.7207692932710663
# Max stretch relative to previous: 1.2002387993029007
#
# Projecting to constraint
# Error: 3.72512e-09
# Projecting to constraint took 0.278825044631958 s
# Range of conformal scale factors: [-0.3036649502602058, 0.14237187109181795]
# Flips: 10595
# Energy after projection: 87.36126436582562
# Optimization energy: 3815.9952557978368
# Max angle error: 3.72512509727585e-09
# Max stretch relative to target: 1.7207692932710663
# Max stretch relative to initial: 1.7207692932710663
# Max stretch relative to previous: 1.2509198536882342
#
# Line step with beta 0.5
# Flips: 10607
# Energy after line step: 79.64216010949897
# Max angle error: 0.4712408385585132
# Optimization energy: 3171.4368334535347
# Max stretch relative to target: 1.534009296522496
# Max stretch relative to initial: 1.534009296522496
# Max stretch relative to previous: 1.0488657681760094
#
# Projecting to constraint
# Error: 7.80531e-12
# Projecting to constraint took 0.2806398868560791 s
# Range of conformal scale factors: [-0.10742641106303485, 0.030743978494569568]
# Flips: 10604
# Energy after projection: 81.731192869555
# Optimization energy: 3339.993943940199
# Max angle error: 7.7964301681277e-12
# Max stretch relative to target: 1.534009296522496
# Max stretch relative to initial: 1.534009296522496
# Max stretch relative to previous: 1.0493296383423405
#
# Total optimization time 7.481267929077148
# Energy at end of iteration 6: 81.731192869555
# Optimization energy: 3339.993943940199
# Max metric distortion: 39.90723237047251
# Norm metric distortion: 358.91536438881633
# Max area distortion: 23.32093122875122
# Norm area distortion: 131.4626410403801
# Max conformal scale: 0.4230109294276818
# Norm conformal scale: 15.112137440611372
# Full mesh energy at end of iteration 6: 114.71489025674374
# Max angle error: 7.7964301681277e-12
# Convergence ratio at end of iteration 6: 0.2724440036250831
#
#
# Iteration 7
# L2 energy at start of iteration 7: 81.731192869555
#
# Optimization energy: 3339.993943940199
# Getting line search direction
# Flips: 10604
# gk 1.984483187510639
# Finding direction took 0.25391316413879395 s
# Delta lambdas norm 22.291410324508917 in iteration 7
#
# Line step with beta 1.0
# Flips: 10500
# Energy after line step: 78.6325690350286
# Max angle error: 1.805095151959705
# Optimization energy: 3091.540456524269
# Max stretch relative to target: 1.6510087236042734
# Max stretch relative to initial: 1.6510087236042734
# Max stretch relative to previous: 1.1986696570624849
#
# Projecting to constraint
# Error: 7.10543e-15
# Projecting to constraint took 0.3273506164550781 s
# Range of conformal scale factors: [-0.38422870993994507, 0.1281385474954752]
# Flips: 10479
# Energy after projection: 91.04999409004441
# Optimization energy: 4145.050711898561
# Max angle error: 1.4210854715202004e-14
# Max stretch relative to target: 1.662177034576072
# Max stretch relative to initial: 1.662177034576072
# Max stretch relative to previous: 1.2043014968168821
#
# Line step with beta 0.5
# Flips: 10576
# Energy after line step: 79.41855990195593
# Max angle error: 0.570643566811194
# Optimization energy: 3153.6538284502813
# Max stretch relative to target: 1.3667585824059771
# Max stretch relative to initial: 1.3667585824059771
# Max stretch relative to previous: 1.0484916921612886
#
# Projecting to constraint
# Error: 1.82965e-12
# Projecting to constraint took 0.25780200958251953 s
# Range of conformal scale factors: [-0.11386640489207782, 0.05578026403265041]
# Flips: 10572
# Energy after projection: 82.34383413441424
# Optimization energy: 3390.2535099779616
# Max angle error: 1.8349766151004587e-12
# Max stretch relative to target: 1.3505104369298226
# Max stretch relative to initial: 1.3505104369298226
# Max stretch relative to previous: 1.0482123277772493
#
# Line step with beta 0.25
# Flips: 10708
# Energy after line step: 80.39024248314905
# Max angle error: 0.16574463787502935
# Optimization energy: 3231.2955432497515
# Max stretch relative to target: 1.4162943871536706
# Max stretch relative to initial: 1.4162943871536706
# Max stretch relative to previous: 1.0120503179588671
#
# Projecting to constraint
# Error: 1.06581e-14
# Projecting to constraint took 0.27502894401550293 s
# Range of conformal scale factors: [-0.030471443237994573, 0.01558918468319172]
# Flips: 10709
# Energy after projection: 81.13166707418732
# Optimization energy: 3291.1737011183855
# Max angle error: 1.2434497875801753e-14
# Max stretch relative to target: 1.4162943871536706
# Max stretch relative to initial: 1.4162943871536706
# Max stretch relative to previous: 1.0117539766059944
#
# Total optimization time 8.981297969818115
# Energy at end of iteration 7: 81.13166707418732
# Optimization energy: 3291.1737011183855
# Max metric distortion: 23.960417982940815
# Norm metric distortion: 349.9552047969515
# Max area distortion: 24.14575388003747
# Norm area distortion: 131.04982684988374
# Max conformal scale: 0.5014153069524355
# Norm conformal scale: 15.019224239689569
# Full mesh energy at end of iteration 7: 113.86797469832459
# Max angle error: 1.2434497875801753e-14
# Convergence ratio at end of iteration 7: 0.2727405479091264
#
#
# Iteration 8
# L2 energy at start of iteration 8: 81.13166707418732
#
# Optimization energy: 3291.1737011183855
# Getting line search direction
# Flips: 10709
# gk 1.7669027152632282
# Finding direction took 0.3526749610900879 s
# Delta lambdas norm 17.350754915766743 in iteration 8
#
# Line step with beta 0.5
# Flips: 10893
# Energy after line step: 79.72804324496948
# Max angle error: 0.0484216918899687
# Optimization energy: 3178.280439835862
# Max stretch relative to target: 1.4753038437975865
# Max stretch relative to initial: 1.4753038437975865
# Max stretch relative to previous: 1.0042426094575752
#
# Projecting to constraint
# Error: 1.31345e-09
# Projecting to constraint took 0.2336740493774414 s
# Range of conformal scale factors: [-0.00923702654655834, 0.004647324999613666]
# Flips: 10893
# Energy after projection: 79.81397027655943
# Optimization energy: 3185.134925653756
# Max angle error: 1.313441799766224e-09
# Max stretch relative to target: 1.4753038437975865
# Max stretch relative to initial: 1.4753038437975865
# Max stretch relative to previous: 1.0041541750265686
#
# Total optimization time 9.781306982040405
# Energy at end of iteration 8: 79.81397027655943
# Optimization energy: 3185.134925653756
# Max metric distortion: 31.530134049544493
# Norm metric distortion: 399.69791809044654
# Max area distortion: 28.95974731473256
# Norm area distortion: 146.0935969449231
# Max conformal scale: 0.408476978780488
# Norm conformal scale: 14.735046816476656
# Full mesh energy at end of iteration 8: 111.9034177710572
# Max angle error: 1.313441799766224e-09
# Convergence ratio at end of iteration 8: 0.21385921849604175
#
#
# Iteration 9
# L2 energy at start of iteration 9: 79.81397027655943
#
# Optimization energy: 3185.134925653756
# Getting line search direction
# Flips: 10893
# gk 1.8799985561658543
# Finding direction took 0.2673757076263428 s
# Delta lambdas norm 9.88998295622663 in iteration 9
#
# Line step with beta 1.0
# Flips: 10951
# Energy after line step: 79.19885155594396
# Max angle error: 0.4973183919359272
# Optimization energy: 3136.2290438902237
# Max stretch relative to target: 1.486242360592695
# Max stretch relative to initial: 1.486242360592695
# Max stretch relative to previous: 1.0355158039019958
#
# Projecting to constraint
# Error: 3.90799e-14
# Projecting to constraint took 0.3496830463409424 s
# Range of conformal scale factors: [-0.12396703701343027, 0.0452269097865069]
# Flips: 10947
# Energy after projection: 79.70916378494312
# Optimization energy: 3176.7753956474435
# Max angle error: 3.730349362740526e-14
# Max stretch relative to target: 1.4505296832778172
# Max stretch relative to initial: 1.4505296832778172
# Max stretch relative to previous: 1.0273959901250145
#
# Total optimization time 10.600899934768677
# Energy at end of iteration 9: 79.70916378494312
# Optimization energy: 3176.7753956474435
# Max metric distortion: 28.441803584857595
# Norm metric distortion: 427.3840812587327
# Max area distortion: 32.81827856315213
# Norm area distortion: 181.9197816784971
# Max conformal scale: 0.42940083393232015
# Norm conformal scale: 13.98326530905344
# Full mesh energy at end of iteration 9: 111.71383615660602
# Max angle error: 3.730349362740526e-14
# Convergence ratio at end of iteration 9: 0.12391293055535692
#
#
# Error: 3.90799e-14
# Flips: 10947
# Angle error: 3.90799e-14
# Plot saved to file ../output/hemispheres_isotropic/hemisphere_2/opt_mesh.html.
# Plot saved to file ../output/hemispheres_isotropic/hemisphere_2/opt_layout.html.
# Flips: 1598
# Starting optimization
# Initial l2 energy: 0.0
# Initial optimization energy: 0.0
# Initial max angle error: 0.1418829344132284
#
# Performing initial conformal projection
# Error: 1.42109e-14
#
# First projection complete
# Flips: 1592
# L2 energy before optimization: 550.0790431334527
# Optimization energy: 151293.47684730747
# Max angle error before optimization: 1.5987211554602254e-14
#
# Error: 1.59872e-14
# Flips: 1592
# Angle error: 1.59872e-14
# Plot saved to file ../output/hemispheres_isotropic/hemisphere_3/conf_mesh.html.
# Plot saved to file ../output/hemispheres_isotropic/hemisphere_3/conf_layout.html.
# Flips: 1598
# Starting optimization
# Initial l2 energy: 0.0
# Initial optimization energy: 0.0
# Initial max angle error: 0.1418829344132284
#
# Performing initial conformal projection
# Error: 1.42109e-14
#
# First projection complete
# Flips: 1592
# L2 energy before optimization: 550.0790431334527
# Optimization energy: 151293.47684730747
# Max angle error before optimization: 1.5987211554602254e-14
#
# Iteration 0
# L2 energy at start of iteration 0: 550.0790431334527
#
# Optimization energy: 151293.47684730747
# Getting line search direction
# Flips: 1592
# gk 6.155500575390634
# Finding direction took 0.23699712753295898 s
# Delta lambdas norm 541.1539502953141 in iteration 0
#
# Line step with beta 1.0
# Flips: 9263
# Energy after line step: 98.68817443070868
# Max angle error: 2.2943291518387348
# Optimization energy: 4869.677886232992
# Max stretch relative to target: 1.4617986020055602
# Max stretch relative to initial: 1.4617986020055602
# Max stretch relative to previous: 10.834430973567361
#
# Projecting to constraint
# Error: 1.88294e-13
# Projecting to constraint took 0.4034707546234131 s
# Range of conformal scale factors: [-0.6509662675716136, 0.20547038338230664]
# Flips: 9009
# Energy after projection: 175.42428374427578
# Optimization energy: 15386.83966359609
# Max angle error: 1.900701818158268e-13
# Max stretch relative to target: 1.7154267827501435
# Max stretch relative to initial: 1.7154267827501435
# Max stretch relative to previous: 6.019856147514341
#
# Total optimization time 1.3220269680023193
# Energy at end of iteration 0: 175.42428374427578
# Optimization energy: 15386.83966359609
# Max metric distortion: 65.95112425818395
# Norm metric distortion: 531.0931370165314
# Max area distortion: 1093.834511309483
# Norm area distortion: 1867.2633908941182
# Max conformal scale: 3.08330009162712
# Norm conformal scale: 158.81879929832968
# Full mesh energy at end of iteration 0: 247.64813963869065
# Max angle error: 1.900701818158268e-13
# Convergence ratio at end of iteration 0: 0.9837748902643191
#
#
# Iteration 1
# L2 energy at start of iteration 1: 175.42428374427578
#
# Optimization energy: 15386.83966359609
# Getting line search direction
# Flips: 9009
# gk 2.2687505923244364
# Finding direction took 0.2843441963195801 s
# Delta lambdas norm 128.28263302837354 in iteration 1
#
# Line step with beta 1.0
# Flips: 14252
# Energy after line step: 119.65469229467392
# Max angle error: 6.488555668546976
# Optimization energy: 7158.622694066549
# Max stretch relative to target: 2.8001361155883826
# Max stretch relative to initial: 2.8001361155883826
# Max stretch relative to previous: 2.122634936580764
#
# Projecting to constraint
# Error: 7.10543e-15
# Projecting to constraint took 0.5040619373321533 s
# Range of conformal scale factors: [-1.294544844049089, 0.43365360472138864]
# Flips: 13865
# Energy after projection: 222.34677466004962
# Optimization energy: 24719.04410086344
# Max angle error: 2.1316282072803006e-14
# Max stretch relative to target: 2.0123487992549216
# Max stretch relative to initial: 2.0123487992549216
# Max stretch relative to previous: 2.4995882282309383
#
# Line step with beta 0.5
# Flips: 11260
# Energy after line step: 135.7621223813533
# Max angle error: 2.736755102403439
# Optimization energy: 9215.676936744774
# Max stretch relative to target: 1.6502456210455307
# Max stretch relative to initial: 1.6502456210455307
# Max stretch relative to previous: 1.2495268977858707
#
# Projecting to constraint
# Error: 2.44249e-12
# Projecting to constraint took 0.4021720886230469 s
# Range of conformal scale factors: [-0.5014082350434804, 0.16236621681910066]
# Flips: 11206
# Energy after projection: 172.22015286673496
# Optimization energy: 14829.89052672078
# Max angle error: 2.440714297335944e-12
# Max stretch relative to target: 1.554683744602729
# Max stretch relative to initial: 1.554683744602729
# Max stretch relative to previous: 1.2010356792964232
#
# Total optimization time 2.853541135787964
# Energy at end of iteration 1: 172.22015286673496
# Optimization energy: 14829.89052672078
# Max metric distortion: 46.210799196780876
# Norm metric distortion: 389.9863458076336
# Max area distortion: 100.19552817076953
# Norm area distortion: 266.89188166097694
# Max conformal scale: 0.8303541789338243
# Norm conformal scale: 43.360009407432194
# Full mesh energy at end of iteration 1: 243.18285924879916
# Max angle error: 2.440714297335944e-12
# Convergence ratio at end of iteration 1: 0.7312706672662102
#
#
# Iteration 2
# L2 energy at start of iteration 2: 172.22015286673496
#
# Optimization energy: 14829.89052672078
# Getting line search direction
# Flips: 11206
# gk 2.019619916896721
# Finding direction took 0.29380297660827637 s
# Delta lambdas norm 125.01442694836108 in iteration 2
#
# Line step with beta 1.0
# Flips: 15381
# Energy after line step: 118.45325705308545
# Max angle error: 4.651262826916248
# Optimization energy: 7015.5870532421695
# Max stretch relative to target: 2.3446655341809373
# Max stretch relative to initial: 2.3446655341809373
# Max stretch relative to previous: 2.5165580987021103
#
# Projecting to constraint
# Error: 1.98157e-09
# Projecting to constraint took 0.4170651435852051 s
# Range of conformal scale factors: [-1.1525873426398185, 0.38194334273619496]
# Flips: 15105
# Energy after projection: 208.3522748886929
# Optimization energy: 21705.335225646726
# Max angle error: 1.9815669105582856e-09
# Max stretch relative to target: 2.3446655341809373
# Max stretch relative to initial: 2.3446655341809373
# Max stretch relative to previous: 3.109983915285033
#
# Line step with beta 0.5
# Flips: 13654
# Energy after line step: 133.93403541914267
# Max angle error: 2.262221955047469
# Optimization energy: 8969.162921828081
# Max stretch relative to target: 1.51118560455361
# Max stretch relative to initial: 1.51118560455361
# Max stretch relative to previous: 1.326001149830216
#
# Projecting to constraint
# Error: 3.05533e-13
# Projecting to constraint took 0.42155909538269043 s
# Range of conformal scale factors: [-0.3473919664913247, 0.16177246015827448]
# Flips: 13600
# Energy after projection: 165.10926658650268
# Optimization energy: 13630.534956366406
# Max angle error: 3.090860900556436e-13
# Max stretch relative to target: 1.522704425614236
# Max stretch relative to initial: 1.522704425614236
# Max stretch relative to previous: 1.381931952654308
#
# Total optimization time 4.32389497756958
# Energy at end of iteration 2: 165.10926658650268
# Optimization energy: 13630.534956366406
# Max metric distortion: 40.25401031049418
# Norm metric distortion: 516.657889951656
# Max area distortion: 42.772723053111434
# Norm area distortion: 213.26574541039633
# Max conformal scale: 0.8366323199550028
# Norm conformal scale: 42.31096663240115
# Full mesh energy at end of iteration 2: 233.04305604709106
# Max angle error: 3.090860900556436e-13
# Convergence ratio at end of iteration 2: 0.7258989431109031
#
#
# Iteration 3
# L2 energy at start of iteration 3: 165.10926658650268
#
# Optimization energy: 13630.534956366406
# Getting line search direction
# Flips: 13600
# gk 1.9649208795348354
# Finding direction took 0.3170742988586426 s
# Delta lambdas norm 117.14161647057149 in iteration 3
#
# Line step with beta 1.0
# Flips: 16214
# Energy after line step: 116.35682877323995
# Max angle error: 5.837491880630068
# Optimization energy: 6769.45580108254
# Max stretch relative to target: 2.5252344570303302
# Max stretch relative to initial: 2.5252344570303302
# Max stretch relative to previous: 2.286268189505
#
# Projecting to constraint
# Error: 8.88178e-15
# Projecting to constraint took 0.47902989387512207 s
# Range of conformal scale factors: [-1.1417317270579708, 0.4884835741882712]
# Flips: 15951
# Energy after projection: 231.305016133683
# Optimization energy: 26751.00524430168
# Max angle error: 2.1316282072803006e-14
# Max stretch relative to target: 2.146223084741047
# Max stretch relative to initial: 2.146223084741047
# Max stretch relative to previous: 2.791093539145566
#
# Line step with beta 0.5
# Flips: 14806
# Energy after line step: 130.26684605115122
# Max angle error: 2.6739348673846557
# Optimization energy: 8484.725590057165
# Max stretch relative to target: 1.6032352266337933
# Max stretch relative to initial: 1.6032352266337933
# Max stretch relative to previous: 1.281847921850521
#
# Projecting to constraint
# Error: 1.20792e-13
# Projecting to constraint took 0.5130560398101807 s
# Range of conformal scale factors: [-0.4134358828575345, 0.22605743813675863]
# Flips: 14728
# Energy after projection: 169.95167450657766
# Optimization energy: 14441.78583379486
# Max angle error: 1.1546319456101628e-13
# Max stretch relative to target: 1.604281511309034
# Max stretch relative to initial: 1.604281511309034
# Max stretch relative to previous: 1.3252180053546374
#
# Line step with beta 0.25
# Flips: 14071
# Energy after line step: 145.79995079591046
# Max angle error: 0.9770520202217909
# Optimization energy: 10628.812826044956
# Max stretch relative to target: 1.4690516793900759
# Max stretch relative to initial: 1.4690516793900759
# Max stretch relative to previous: 1.0681404219133646
#
# Projecting to constraint
# Error: 1.68814e-10
# Projecting to constraint took 0.37114596366882324 s
# Range of conformal scale factors: [-0.14530988103093068, 0.07121601196587013]
# Flips: 14077
# Energy after projection: 155.53991026695127
# Optimization energy: 12096.331842925627
# Max angle error: 1.68821401302921e-10
# Max stretch relative to target: 1.5125987538775016
# Max stretch relative to initial: 1.5125987538775016
# Max stretch relative to previous: 1.0647965587834427
#
# Total optimization time 6.475647926330566
# Energy at end of iteration 3: 155.53991026695127
# Optimization energy: 12096.331842925627
# Max metric distortion: 25.88761241675245
# Norm metric distortion: 425.8690960799973
# Max area distortion: 14.511340915340993
# Norm area distortion: 149.45904336957585
# Max conformal scale: 0.8025143059461249
# Norm conformal scale: 39.42018330516633
# Full mesh energy at end of iteration 3: 219.5109938188566
# Max angle error: 1.68821401302921e-10
# Convergence ratio at end of iteration 3: 0.709479358078304
#
#
# Iteration 4
# L2 energy at start of iteration 4: 155.53991026695127
#
# Optimization energy: 12096.331842925627
# Getting line search direction
# Flips: 14077
# gk 1.9472163377102145
# Finding direction took 0.42353010177612305 s
# Delta lambdas norm 95.03434816412914 in iteration 4
#
# Line step with beta 0.5
# Flips: 16388
# Energy after line step: 131.981128145079
# Max angle error: 0.9970983544287169
# Optimization energy: 8709.509093223882
# Max stretch relative to target: 1.560980928549237
# Max stretch relative to initial: 1.560980928549237
# Max stretch relative to previous: 1.0839367012889465
#
# Projecting to constraint
# Error: 2.53634e-10
# Projecting to constraint took 0.44579100608825684 s
# Range of conformal scale factors: [-0.22259289185714484, 0.09205044282555595]
# Flips: 16330
# Energy after projection: 137.97045888802248
# Optimization energy: 9517.92376288575
# Max angle error: 2.5363000588640716e-10
# Max stretch relative to target: 1.560980928549237
# Max stretch relative to initial: 1.560980928549237
# Max stretch relative to previous: 1.0941791107001757
#
# Total optimization time 7.5814549922943115
# Energy at end of iteration 4: 137.97045888802248
# Optimization energy: 9517.92376288575
# Max metric distortion: 79.84079903706622
# Norm metric distortion: 711.5064179171762
# Max area distortion: 70.78487292104701
# Norm area distortion: 224.21820047995416
# Max conformal scale: 0.7616427388009959
# Norm conformal scale: 36.26203164859879
# Full mesh energy at end of iteration 4: 194.43819174560142
# Max angle error: 2.5363000588640716e-10
# Convergence ratio at end of iteration 4: 0.6109965474521802
#
#
# Iteration 5
# L2 energy at start of iteration 5: 137.97045888802248
#
# Optimization energy: 9517.92376288575
# Getting line search direction
# Flips: 16330
# gk 2.030163556648131
# Finding direction took 0.34445905685424805 s
# Delta lambdas norm 68.87282735865419 in iteration 5
#
# Line step with beta 1.0
# Flips: 17607
# Energy after line step: 119.5507472764504
# Max angle error: 10.559400002017068
# Optimization energy: 7146.190587178856
# Max stretch relative to target: 2.832040160958945
# Max stretch relative to initial: 2.832040160958945
# Max stretch relative to previous: 1.7734347373348573
#
# Projecting to constraint
# Error: 3.69482e-13
# Projecting to constraint took 0.6880230903625488 s
# Range of conformal scale factors: [-1.1195127319339335, 0.40068725558187035]
# Flips: 17492
# Energy after projection: 194.9730525893196
# Optimization energy: 19007.245617998793
# Max angle error: 3.730349362740526e-13
# Max stretch relative to target: 2.832040160958945
# Max stretch relative to initial: 2.832040160958945
# Max stretch relative to previous: 2.322411199682909
#
# Line step with beta 0.5
# Flips: 16905
# Energy after line step: 124.41160622293589
# Max angle error: 2.402975789438292
# Optimization energy: 7739.12388148543
# Max stretch relative to target: 1.9213033622628362
# Max stretch relative to initial: 1.9213033622628362
# Max stretch relative to previous: 1.1775896435802367
#
# Projecting to constraint
# Error: 2.01847e-11
# Projecting to constraint took 0.5438430309295654 s
# Range of conformal scale factors: [-0.4443772406306982, 0.24973647513113614]
# Flips: 16856
# Energy after projection: 150.8421867956708
# Optimization energy: 11376.682658650023
# Max angle error: 2.0186519122944446e-11
# Max stretch relative to target: 1.9213033622628362
# Max stretch relative to initial: 1.9213033622628362
# Max stretch relative to previous: 1.2530100544281038
#
# Line step with beta 0.25
# Flips: 16657
# Energy after line step: 130.23279539961408
# Max angle error: 0.8818890697953279
# Optimization energy: 8480.290498798871
# Max stretch relative to target: 1.6097285260172407
# Max stretch relative to initial: 1.6097285260172407
# Max stretch relative to previous: 1.043453315577711
#
# Projecting to constraint
# Error: 5.45974e-10
# Projecting to constraint took 0.4940500259399414 s
# Range of conformal scale factors: [-0.16290152262309374, 0.08573221716415216]
# Flips: 16643
# Energy after projection: 137.23014597734428
# Optimization energy: 9416.05648248161
# Max angle error: 5.459739327307034e-10
# Max stretch relative to target: 1.6097285260172407
# Max stretch relative to initial: 1.6097285260172407
# Max stretch relative to previous: 1.049613171324041
#
# Total optimization time 10.117802858352661
# Energy at end of iteration 5: 137.23014597734428
# Optimization energy: 9416.05648248161
# Max metric distortion: 66.93812337292515
# Norm metric distortion: 644.2812537687405
# Max area distortion: 352.2050792013615
# Norm area distortion: 530.3424126715219
# Max conformal scale: 0.7692692567260674
# Norm conformal scale: 28.517889147170376
# Full mesh energy at end of iteration 5: 193.41949735900448
# ...
# L2 energy at start of iteration 52: 150.33122816011874
#
# Optimization energy: 11299.739080064839
# Getting line search direction
# Flips: 14097
# gk 4.4873271211241015
# Finding direction took 0.2291550636291504 s
# Delta lambdas norm 27.127347765330676 in iteration 52
#
# Line step with beta 0.0625
# Flips: 14147
# Energy after line step: 150.03454974612367
# Max angle error: 0.07443474500072256
# Optimization energy: 11255.18305876103
# Max stretch relative to target: 4.889675643962289
# Max stretch relative to initial: 4.889675643962289
# Max stretch relative to previous: 1.0006422533893242
#
# Projecting to constraint
# Error: 8.88178e-15
# Projecting to constraint took 0.2062699794769287 s
# Range of conformal scale factors: [-0.0014737589400189103, 0.004008690130501493]
# Flips: 14143
# Energy after projection: 150.05008783843226
# Optimization energy: 11257.514430160618
# Max angle error: 2.1316282072803006e-14
# Max stretch relative to target: 4.888854753867295
# Max stretch relative to initial: 4.888854753867295
# Max stretch relative to previous: 1.000633642298675
#
# Total optimization time 33.129053831100464
# Energy at end of iteration 52: 150.05008783843226
# Optimization energy: 11257.514430160618
# Max metric distortion: 10467.504935640462
# Norm metric distortion: 26590.066030867292
# Max area distortion: 38374.95917767185
# Norm area distortion: 105664.55724941826
# Max conformal scale: 1.5034699308240131
# Norm conformal scale: 21.520514291816845
# Full mesh energy at end of iteration 52: 211.7049749954836
# Max angle error: 2.1316282072803006e-14
# Convergence ratio at end of iteration 52: 0.18045051648508562
#
#
# Iteration 53
# L2 energy at start of iteration 53: 150.05008783843226
#
# Optimization energy: 11257.514430160618
# Getting line search direction
# Flips: 14143
# gk 4.538954725157998
# Finding direction took 0.23141098022460938 s
# Delta lambdas norm 25.706828051792595 in iteration 53
#
# Line step with beta 0.125
# Flips: 14153
# Energy after line step: 149.5330874718303
# Max angle error: 0.3578699084965926
# Optimization energy: 11180.072124429025
# Max stretch relative to target: 5.15791580323927
# Max stretch relative to initial: 5.15791580323927
# Max stretch relative to previous: 1.0035395091350683
#
# Projecting to constraint
# Error: 1.73266e-11
# Projecting to constraint took 0.20322823524475098 s
# Range of conformal scale factors: [-0.014289146483799066, 0.024220374599431074]
# Flips: 14151
# Energy after projection: 149.62632082408834
# Optimization energy: 11194.017941676506
# Max angle error: 1.7319479184152442e-11
# Max stretch relative to target: 5.159849449144359
# Max stretch relative to initial: 5.159849449144359
# Max stretch relative to previous: 1.0037935136919256
#
# Total optimization time 33.64109396934509
# Energy at end of iteration 53: 149.62632082408834
# Optimization energy: 11194.017941676506
# Max metric distortion: 12967.365777452376
# Norm metric distortion: 32491.853277471742
# Max area distortion: 42366.366566167584
# Norm area distortion: 121427.78126654978
# Max conformal scale: 1.524856402019469
# Norm conformal scale: 21.30298440961704
# Full mesh energy at end of iteration 53: 211.09648643307872
# Max angle error: 1.7319479184152442e-11
# Convergence ratio at end of iteration 53: 0.17132164613907222
#
#
# Iteration 54
# L2 energy at start of iteration 54: 149.62632082408834
#
# Optimization energy: 11194.017941676506
# Getting line search direction
# Flips: 14151
# gk 4.649058974659836
# Finding direction took 0.21029400825500488 s
# Delta lambdas norm 25.016057299658385 in iteration 54
#
# Line step with beta 0.25
# Flips: 14110
# Energy after line step: 148.7085976567282
# Max angle error: 4.107987334081244
# Optimization energy: 11057.123508515331
# Max stretch relative to target: 5.554067944231514
# Max stretch relative to initial: 5.554067944231514
# Max stretch relative to previous: 1.0702908250678564
#
# Projecting to constraint
# Error: 6.32383e-13
# Projecting to constraint took 0.18569207191467285 s
# Range of conformal scale factors: [-0.1789713011217192, 0.4435813397834795]
# Flips: 14109
# Energy after projection: 150.50325487854482
# Optimization energy: 11325.614864518113
# Max angle error: 6.306066779870889e-13
# Max stretch relative to target: 5.506598018532436
# Max stretch relative to initial: 5.506598018532436
# Max stretch relative to previous: 1.1143164401786425
#
# Line step with beta 0.125
# Flips: 14141
# Energy after line step: 149.13538572853116
# Max angle error: 1.5420169281341707
# Optimization energy: 11120.681638198888
# Max stretch relative to target: 5.353199942823652
# Max stretch relative to initial: 5.353199942823652
# Max stretch relative to previous: 1.0174209613203025
#
# Projecting to constraint
# Error: 2.82121e-11
# Projecting to constraint took 0.1859581470489502 s
# Range of conformal scale factors: [-0.06496987414507398, 0.16918863690426414]
# Flips: 14136
# Energy after projection: 149.69695189826044
# Optimization energy: 11204.58870381505
# Max angle error: 2.8213875680194178e-11
# Max stretch relative to target: 5.360059790835471
# Max stretch relative to initial: 5.360059790835471
# Max stretch relative to previous: 1.022402851820943
#
# Line step with beta 0.0625
# Flips: 14158
# Energy after line step: 149.37287249171743
# Max angle error: 0.4107615970941634
# Optimization energy: 11156.127518213438
# Max stretch relative to target: 5.255602220556236
# Max stretch relative to initial: 5.255602220556236
# Max stretch relative to previous: 1.0043457973527599
#
# Projecting to constraint
# Error: 6.69521e-10
# Projecting to constraint took 0.21239614486694336 s
# Range of conformal scale factors: [-0.025451723880934828, 0.04039227197230575]
# Flips: 14155
# Energy after projection: 149.5160702693404
# Optimization energy: 11177.527634393167
# Max angle error: 6.69524879981509e-10
# Max stretch relative to target: 5.264850453940543
# Max stretch relative to initial: 5.264850453940543
# Max stretch relative to previous: 1.0034962557008065
#
# Total optimization time 34.58851194381714
# Energy at end of iteration 54: 149.5160702693404
# Optimization energy: 11177.527634393167
# Max metric distortion: 14219.216724495614
# Norm metric distortion: 35233.19641462055
# Max area distortion: 43508.9887938252
# Norm area distortion: 125386.97144566427
# Max conformal scale: 1.5652087563221557
# Norm conformal scale: 20.958611848208655
# Full mesh energy at end of iteration 54: 210.94175008606967
# Max angle error: 6.69524879981509e-10
# Convergence ratio at end of iteration 54: 0.1671902186853147
#
#
# Iteration 55
# L2 energy at start of iteration 55: 149.5160702693404
#
# Optimization energy: 11177.527634393167
# Getting line search direction
# Flips: 14155
# gk 4.690112399663193
# Finding direction took 0.20845890045166016 s
# Delta lambdas norm 25.076343451232844 in iteration 55
#
# Line step with beta 0.125
# Flips: 14170
# Energy after line step: 149.02239723584447
# Max angle error: 3.2371186201833257
# Optimization energy: 11103.837438958912
# Max stretch relative to target: 5.64967187420858
# Max stretch relative to initial: 5.64967187420858
# Max stretch relative to previous: 1.0173242697276828
#
# Projecting to constraint
# Error: 1.24345e-14
# Projecting to constraint took 0.20400094985961914 s
# Range of conformal scale factors: [-0.1036603599899672, 0.2845102962264508]
# Flips: 14166
# Energy after projection: 149.70612012442098
# Optimization energy: 11205.961201353783
# Max angle error: 1.7763568394002505e-14
# Max stretch relative to target: 5.666664341091189
# Max stretch relative to initial: 5.666664341091189
# Max stretch relative to previous: 1.041119490600313
#
# Line step with beta 0.0625
# Flips: 14156
# Energy after line step: 149.2612097415295
# Max angle error: 1.9436799578959043
# Optimization energy: 11139.454366752432
# Max stretch relative to target: 5.453750041739754
# Max stretch relative to initial: 5.453750041739754
# Max stretch relative to previous: 1.0043217287621737
#
# Projecting to constraint
# Error: 2.27274e-10
# Projecting to constraint took 0.19245266914367676 s
# Range of conformal scale factors: [-0.03631439286832373, 0.11992357699564378]
# Flips: 14157
# Energy after projection: 149.48159848287327
# Optimization energy: 11172.37414249747
# Max angle error: 2.2726887038970744e-10
# Max stretch relative to target: 5.45292267669174
# Max stretch relative to initial: 5.45292267669174
# Max stretch relative to previous: 1.0090325202461359
#
# Total optimization time 35.30801296234131
# Energy at end of iteration 55: 149.48159848287327
# Optimization energy: 11172.37414249747
# Max metric distortion: 16280.807868234813
# Norm metric distortion: 39925.358947244786
# Max area distortion: 43566.34503566287
# Norm area distortion: 128320.68862319332
# Max conformal scale: 1.585114886785199
# Norm conformal scale: 20.87381607648064
# Full mesh energy at end of iteration 55: 210.88930449344613
# Max angle error: 2.2726887038970744e-10
# Convergence ratio at end of iteration 55: 0.16771671035802346
#
#
# Iteration 56
# L2 energy at start of iteration 56: 149.48159848287327
#
# Optimization energy: 11172.37414249747
# Getting line search direction
# Flips: 14157
# gk 4.761566148996967
# Finding direction took 0.2088479995727539 s
# Delta lambdas norm 24.95185192195646 in iteration 56
#
# Line step with beta 0.125
# Flips: 14151
# Energy after line step: 148.99270989492723
# Max angle error: 1.3861850657745585
# Optimization energy: 11099.413800916973
# Max stretch relative to target: 5.581828654990889
# Max stretch relative to initial: 5.581828654990889
# Max stretch relative to previous: 1.0136279116329323
#
# Projecting to constraint
# Error: 2.30926e-14
# Projecting to constraint took 0.19205093383789062 s
# Range of conformal scale factors: [-0.10224304397334087, 0.10906847820991679]
# Flips: 14164
# Energy after projection: 149.7454917601093
# Optimization energy: 11211.856151238482
# Max angle error: 2.1316282072803006e-14
# Max stretch relative to target: 5.580634527087224
# Max stretch relative to initial: 5.580634527087224
# Max stretch relative to previous: 1.0121252685773063
#
# Line step with beta 0.0625
# Flips: 14176
# Energy after line step: 149.22920602894834
# Max angle error: 0.5381707871006771
# Optimization energy: 11134.677966015155
# Max stretch relative to target: 5.516986399255496
# Max stretch relative to initial: 5.516986399255496
# Max stretch relative to previous: 1.0034011938484357
#
# Projecting to constraint
# Error: 1.06581e-14
# Projecting to constraint took 0.21254611015319824 s
# Range of conformal scale factors: [-0.03565077235378665, 0.02282723539963354]
# Flips: 14173
# Energy after projection: 149.4154765100736
# Optimization energy: 11162.492310366179
# Max angle error: 1.5987211554602254e-14
# Max stretch relative to target: 5.5211178768154445
# Max stretch relative to initial: 5.5211178768154445
# Max stretch relative to previous: 1.0036461521314015
#
# Total optimization time 36.0332977771759
# Energy at end of iteration 56: 149.4154765100736
# Optimization energy: 11162.492310366179
# Max metric distortion: 17303.46039833333
# Norm metric distortion: 41838.37601368088
# Max area distortion: 44361.32253316836
# Norm area distortion: 131331.70647963043
# Max conformal scale: 1.6154850899870579
# Norm conformal scale: 20.840745866415595
# Full mesh energy at end of iteration 56: 210.79857218985686
# Max angle error: 1.5987211554602254e-14
# Convergence ratio at end of iteration 56: 0.16692256555455084
#
#
# Iteration 57
# L2 energy at start of iteration 57: 149.4154765100736
#
# Optimization energy: 11162.492310366179
# Getting line search direction
# Flips: 14173
# gk 4.786846799260411
# Finding direction took 0.21194696426391602 s
# Delta lambdas norm 25.530823372596295 in iteration 57
#
# Line step with beta 0.125
# Flips: 14171
# Energy after line step: 148.9033700714452
# Max angle error: 0.7812981008220667
# Optimization energy: 11086.106809316883
# Max stretch relative to target: 5.887840199510804
# Max stretch relative to initial: 5.887840199510804
# Max stretch relative to previous: 1.0238452455475169
#
# Projecting to constraint
# Error: 7.10543e-15
# Projecting to constraint took 0.18325304985046387 s
# Range of conformal scale factors: [-0.12766976400787786, 0.05428938270321868]
# Flips: 14167
# Energy after projection: 149.88725633445497
# Optimization energy: 11233.094805735307
# Max angle error: 1.7763568394002505e-14
# Max stretch relative to target: 5.874547472450313
# Max stretch relative to initial: 5.874547472450313
# Max stretch relative to previous: 1.0243297513164147
#
# Line step with beta 0.0625
# Flips: 14166
# Energy after line step: 149.15110772741698
# Max angle error: 0.2881859040167445
# Optimization energy: 11123.026468157774
# Max stretch relative to target: 5.701437770822989
# Max stretch relative to initial: 5.701437770822989
# Max stretch relative to previous: 1.0059436479116304
#
# Projecting to constraint
# Error: 5.93303e-13
# Projecting to constraint took 0.1752457618713379 s
# Range of conformal scale factors: [-0.04569269349208944, 0.018530822510657685]
# Flips: 14170
# Energy after projection: 149.44061395692688
# Optimization energy: 11166.248549911625
# Max angle error: 5.986322548778844e-13
# Max stretch relative to target: 5.69823334907132
# Max stretch relative to initial: 5.69823334907132
# Max stretch relative to previous: 1.005939717514167
#
# Line step with beta 0.03125
# Flips: 14157
# Energy after line step: 149.28121862003297
# Max angle error: 0.11198365767480212
# Optimization energy: 11142.44111634104
# Max stretch relative to target: 5.610529679939314
# Max stretch relative to initial: 5.610529679939314
# Max stretch relative to previous: 1.0014848096480622
#
# Projecting to constraint
# Error: 1.06581e-14
# Projecting to constraint took 0.181535005569458 s
# Range of conformal scale factors: [-0.012714456719775193, 0.005054082719199774]
# Flips: 14153
# Energy after projection: 149.35900487434645
# Optimization energy: 11154.056168527524
# Max angle error: 2.3092638912203256e-14
# Max stretch relative to target: 5.609461169012146
# Max stretch relative to initial: 5.609461169012146
# Max stretch relative to previous: 1.0014622849878434
#
# Total optimization time 36.93683099746704
# Energy at end of iteration 57: 149.35900487434645
# Optimization energy: 11154.056168527524
# Max metric distortion: 18359.703935540103
# Norm metric distortion: 44365.787799409525
# Max area distortion: 44595.987770285195
# Norm area distortion: 133752.84568990493
# Max conformal scale: 1.6326356921087795
# Norm conformal scale: 20.790367744187535
# Full mesh energy at end of iteration 57: 210.71711327516226
# Max angle error: 2.3092638912203256e-14
# Convergence ratio at end of iteration 57: 0.17087134458173084
#
#
# Iteration 58
# L2 energy at start of iteration 58: 149.35900487434645
#
# Optimization energy: 11154.056168527524
# Getting line search direction
# Flips: 14153
# gk 4.819120767492591
# Finding direction took 0.21060395240783691 s
# Delta lambdas norm 22.17604341624383 in iteration 58
#
# Line step with beta 0.0625
# Flips: 14176
# Energy after line step: 149.15951604863076
# Max angle error: 0.38243216525328094
# Optimization energy: 11124.280613930869
# Max stretch relative to target: 5.706151577907727
# Max stretch relative to initial: 5.706151577907727
# Max stretch relative to previous: 1.002747935159268
#
# Projecting to constraint
# Error: 8.48523e-10
# Projecting to constraint took 0.18465685844421387 s
# Range of conformal scale factors: [-0.009947977838082758, 0.02699066978089791]
# Flips: 14174
# Energy after projection: 149.1993518054014
# Optimization energy: 11130.223289575966
# Max angle error: 8.485301350447116e-10
# Max stretch relative to target: 5.709846213130729
# Max stretch relative to initial: 5.709846213130729
# Max stretch relative to previous: 1.0023911801570764
#
# Total optimization time 37.39894080162048
# Energy at end of iteration 58: 149.1993518054014
# Optimization energy: 11130.223289575966
# Max metric distortion: 19790.516807610016
# Norm metric distortion: 47726.6725962513
# Max area distortion: 46528.46014779486
# Norm area distortion: 142385.5613775905
# Max conformal scale: 1.6461755874694821
# Norm conformal scale: 20.753265980069973
# Full mesh energy at end of iteration 58: 210.48890287175635
# Max angle error: 8.485301350447116e-10
# Convergence ratio at end of iteration 58: 0.1484747667869119
#
#
# Error: 8.48527e-10
# Flips: 14174
# Angle error: 8.48527e-10
# Plot saved to file ../output/hemispheres_isotropic/hemisphere_20/opt_mesh.html.
# Plot saved to file ../output/hemispheres_isotropic/hemisphere_20/opt_layout.html.

# %% [markdown]
# ## View Hemisphere Plots

# %%
n = 9
m = 'hemisphere_'+str(n)
data_dir = '../data/hemispheres_isotropic'
output_dir = '../output/hemispheres_isotropic/'+m
#data_dir = '../data/hemispheres'
#output_dir = '../output/hemispheres/'+m

v, f = igl.read_triangle_mesh(data_dir+'/'+m+'.obj')
Th_hat = map_to_disk(v,f)
free_angles = True
C, vtx_reindex = fv_to_double(v, f, Th_hat, free_angles)

# Get target and final lambdas
lambdas_target = lambdas_from_mesh(C)
lambdas = np.loadtxt(os.path.join(output_dir, 'opt_lambdas'), dtype=float)

# %%
vw, c = generate_stretch_viewer(C, lambdas, lambdas_target, v, f, Th_hat)
print("Per vertex stretch range: [{}, {}]".format(np.min(c), np.max(c)))
display(vw._renderer)
# Out:
# Per vertex stretch range: [1.076597432712877, 8.181327238324318]
# Renderer(camera=PerspectiveCamera(children=(DirectionalLight(color='white', intensity=0.6, position=(0.0, 2.40…

# %%
vw, c = generate_best_fit_conformal_viewer(C, lambdas, lambdas_target, v, f, Th_hat)
print("Best fit scale range: [{}, {}]".format(np.min(c), np.max(c)))
display(vw._renderer)
print(c)
# Out:
# Best fit scale range: [-0.9397487379687725, 1.5471643849775512]
# Renderer(camera=PerspectiveCamera(children=(DirectionalLight(color='white', intensity=0.6, position=(0.0, 2.40…
# [0.6741307  0.54345952 0.3387621  ... 0.68018544 0.59686617 0.60203543]

# %%
vw_mesh, vw_layout = generate_overlay_viewer(C, lambdas, v, f, Th_hat)
display(vw_mesh._renderer), display(vw_layout._renderer)
# Out:
# Flips: 26986
# Angle error: 7.37952e-11
# Renderer(camera=PerspectiveCamera(children=(DirectionalLight(color='white', intensity=0.6, position=(0.0, 2.40…
# Renderer(camera=PerspectiveCamera(children=(DirectionalLight(color='white', intensity=0.6, position=(-0.174850…
# (None, None)

# %% [markdown]
# # Myles Hand

# %% [markdown]
# ## SLIM on Conformal Output

# %%
data_dir = '../data/open-Myles'
m='hand'

# Initialize mesh from the data set with flat target angles
v, f = igl.read_triangle_mesh(data_dir+'/'+m+'.obj')
Th_hat = map_to_disk(v,f)
free_angles = True
C, vtx_reindex = fv_to_double(v, f, Th_hat, free_angles)

# Get initial (and target) lambdas
lambdas_target = lambdas_from_mesh(C)
lambdas_init = lambdas_from_mesh(C)

# Run conformal method
proj_params = ProjectionParameters()
proj_params.do_reduction = True
opt_params = {}
opt_params['num_iter'] = 0
_, lambdas = optimize_lambdas(C,
                              lambdas_init,
                              lambdas_target,
                              proj_params=proj_params,
                              opt_params=opt_params)

# Get layout
v_cut_o, ft_o, uv_cut_o = build_overlay_layout_FV(C, lambdas, v, f, Th_hat)
# Out:
# Flips: 1106
# Starting optimization
# Initial l2 energy: 0.0
# Initial optimization energy: 0.0
# Initial max angle error: 2.3939457952303904
#
# Performing initial conformal projection
# Error: 5.57954e-12
#
# First projection complete
# Flips: 1009
# L2 energy before optimization: 864.525542280787
# Optimization energy: 373702.2066279444
# Max angle error before optimization: 5.5919713304319885e-12
#
# Error: 5.57776e-12
# Flips: 1009
# Angle error: 5.57776e-12

# %%
vw_mesh, vw_layout = generate_overlay_viewer(C, lambdas, v, f, Th_hat)
display(vw_layout._renderer)
# Out:
# Flips: 1009
# Angle error: 5.57776e-12
# Renderer(camera=PerspectiveCamera(children=(DirectionalLight(color='white', intensity=0.6, position=(-8.513672…

# %%
# Create SLIM optimization class

# Energy choices:
#     ARAP = 0,
#     LOG_ARAP = 1,
#     SYMMETRIC_DIRICHLET = 2,
#     CONFORMAL = 3,
#     EXP_CONFORMAL = 4,
#     EXP_SYMMETRIC_DIRICHLET = 5,
energy_choice = 0
soft_penalty = 0
b = []
bc = np.zeros((0,2))
slim_solver = igl.SLIM(v_cut_o,
                       ft_o,
                       uv_cut_o,
                       b,
                       bc,
                       energy_choice,
                       soft_penalty)
uv = slim_solver.vertices()
v_plane = np.vstack((uv.T, np.zeros(uv.shape[0]))).T

# Display initial energy and vertices
print(slim_solver.energy())
# Out:
# 1.7065135683872632

# %%
# Plot the results
p = plot.subplot(v_cut_o,
                 ft_o,
                 uv=uv,
                 shading={"wireframe": False, "flat": False},
                 s=[1, 2, 0])
plot.subplot(uv,
             ft_o,
             uv=uv,
             shading={"wireframe": True, "flat": False},
             s=[1, 2, 1],
             data=p)
# Out:
# HBox(children=(Output(), Output()))

# %%
# Run solver and display results
num_iter = 50000
slim_solver.solve(num_iter)
uv = slim_solver.vertices()
v_plane = np.vstack((uv.T, np.zeros(uv.shape[0]))).T
print(slim_solver.energy())
# Out:
# 1.1492677841750134

# %%
# Plot the results
p = plot.subplot(v_cut_o,
                 ft_o,
                 uv=uv,
                 shading={"wireframe": True},
                 s=[1, 2, 0])
plot.subplot(uv,
             ft_o,
             uv=uv,
             shading={"wireframe": True},
             s=[1, 2, 1],
             data=p)
# Out:
# HBox(children=(Output(), Output()))

# %%
# Save output to file
output_dir = '../output/SLIM'
os.makedirs(output_dir, exist_ok=True)
igl.write_obj(os.path.join(output_dir, 'hand_overlay.obj'), v_cut_o, ft_o)
igl.write_obj(os.path.join(output_dir, 'hand_SLIM.obj'), v_plane, ft_o)
# Out:
# True

# %%
# Load output from file
v_cut_o, ft_o = igl.read_triangle_mesh(os.path.join(output_dir, 'hand_overlay.obj'))
v_plane, _ = igl.read_triangle_mesh(os.path.join(output_dir, 'hand_SLIM.obj'))
uv = v_plane[:,:2]
energy_choice = 0
soft_penalty = 0
b = []
bc = np.zeros((0,2))
slim_solver = igl.SLIM(v_cut_o,
                       ft_o,
                       uv,
                       b,
                       bc,
                       energy_choice,
                       soft_penalty)

# Display initial energy and vertices
print(slim_solver.energy())
# Out:
# 1.1492677841750139

# %%
# Check the loaded mesh plots
p = plot.subplot(v_cut_o,
                 ft_o,
                 uv=uv,
                 shading={"wireframe": True},
                 s=[1, 2, 0])
plot.subplot(uv,
             ft_o,
             uv=uv,
             shading={"wireframe": True},
             s=[1, 2, 1],
             data=p)
# Out:
# HBox(children=(Output(), Output()))

# %% [markdown]
# # Scratch

# %%
# Check angle constraints before optimization
proj, embed = build_refl_proj(C)
free_v = np.where(np.logical_not(C.fixed_dof))[0]
F, J_F = F_with_jacobian(C, lambdas[proj], False)
F = np.array(F)
np.max(F[free_v])
# Out:
# Flips: 18306
# 2.3583712760455455e-09

# %%
# Run optimization code with 0 iterations (should be the same as conformal)
proj_params = ProjectionParameters()
proj_params.do_reduction = True

opt_params = {}
opt_params['min_ratio'] = 1e-1
opt_params['num_iter'] = 0
opt_params['max_angle'] = 100
opt_params['max_grad_range'] = 10

log_opt, lambdas = optimize_lambdas(C,
                                    lambdas,
                                    lambdas_target,
                                    proj_params=proj_params,
                                    opt_params=opt_params)
# Out:
# Flips: 18306
# Starting optimization
# Initial l2 energy: 90.5765991930801
# Initial optimization energy: 4102.060160691939
# Initial max angle error: 2.3583712760455455e-09
#
# Performing initial conformal projection
# Error: 2.3584e-09
#
# First projection complete
# Flips: 18306
# L2 energy before optimization: 90.5765991930801
# Optimization energy: 4102.060160691939
# Max angle error before optimization: 2.3583712760455455e-09
#
# Error: 2.3584e-09
