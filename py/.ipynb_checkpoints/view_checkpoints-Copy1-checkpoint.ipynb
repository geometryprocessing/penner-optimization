# %%
import os, io, cProfile, pstats, pickle, shutil
import sys
import igl
import meshplot as plot
import pickle
from init_cm_data import *
from conformal_impl.optimization import *
from conformal_impl.layout import *
import matplotlib
import matplotlib.pyplot as plt
import conformal_impl.functions_with_jacobians as FWJ
#from conformal_py import *
# %load_ext autoreload
# %autoreload 2

# %%
def symmetric_stretches(lambdas, lambdas_target):
    l = np.exp(lambdas/2)
    l_target = np.exp(lambdas_target/2)
    return 0.5*(l/l_target + l_target/l)

# %% [markdown]
# ## Checkpoint Lambdas
#
# Methods to open a mesh, Th_hat file with possible interpolation, and lambdas from a checkpoint.

# %%
m = 'raptor50K_0'
#m = 'gearbox'
#m = 'helmet'
data_dir = "../data/extreme_scale_diff_patches"
#data_dir = "../data/cut-Myles-distorted"
#output_dir = "../output/checkpoints"
#checkpoints_dir = "../output/checkpoints/optimization/"
#checkpoints_dir = "../output/high_scale_diff_patches/optimization/"
#checkpoints_dir = "../output/extreme_scale_diff_patches/optimization/"

#m_checkpoints_dir = os.path.join(checkpoints_dir, m+'_lambdas')
#lambdas_init_path = os.path.join(m_checkpoints_dir, 'lambdas_init')
#lambdas_init = np.loadtxt(lambdas_init_path,dtype=float)
#lambdas_path = os.path.join(m_checkpoints_dir, 'lambdas_'+str(k))

# %%
# Open Mesh
v, f = igl.read_triangle_mesh(data_dir+'/'+m+'.obj')
Th_hat = np.loadtxt(data_dir+"/"+m+'_Th_hat',dtype=float)
float_type=float
CMs = prepare_cm_data(v,
                      f,
                      Th_hat,
                      unit_lengths=False,
                      float_type=float_type,
                      tufted_cover=False)
C = CMs[0][0].C
R = CMs[0][0].R
phi = CMs[0][0].phi
elen = CMs[0][0].l
Th_hat_target = CMs[0][0].Th_hat
lambdas_target = 2*np.log(elen)


C_cpp = Connectivity_cpp()
C_cpp.n = C.next_he
C_cpp.prev = C.prev_he
C_cpp.to = C.to
C_cpp.f = C.he2f
C_cpp.h = C.f2he
C_cpp.out = C.out
C_cpp.opp = C.opp

# %%
# Interpolate Th_hat
s = 0.21
s = 1
Th_hat_init = initial_angles(C_cpp, lambdas_target, float_type)
Th_hat = s * Th_hat_target + (1 - s) * Th_hat_init

# %%
# Open checkpoint lambdas
#lambdas_path = "../data/lambdas/raptor50K_0_lambdas_1"
lambdas_path = "../data/lambdas/raptor50K_0_lambdas_2"
#lambdas_path = "../data/lambdas/gearbox_lambdas_0"
lambdas = np.loadtxt(lambdas_path,dtype=float)

# %% [markdown]
# ## Individual Functions

# %%
# Prepare parameters
beta = 0.0001
min_ratio = 0.1
num_opt_iter = 500
proj_params = {}
opt_params = { 'max_angle': 50 }
proj_params_struct = ProjectionParameters()
if 'max_itr' in proj_params:
    proj_params_struct.max_itr = proj_params['max_itr']
if 'bound_norm_thres' in proj_params:
    proj_params_struct.bound_norm_thres = proj_params['bound_norm_thres']
if 'error_eps' in proj_params:
    proj_params_struct.error_eps = proj_params['error_eps']
proj_params_struct.do_reduction = True
p = opt_params['p'] if 'p' in opt_params else 2
require_energy_decr = opt_params['require_energy_decr'] if 'require_energy_decr' in opt_params else True
max_angle_incr = opt_params['max_angle_incr'] if 'max_angle_incr' in opt_params else True

print("Starting optimization")
# FIXME Fix for C
#print_status(C, lambdas_init, lambdas_target, Th_hat, float_type, p=p)
# Out:
# Starting optimization

# %%
# Full optimization
log_s, lambdas = optimize_lambdas(C_cpp,
                                  lambdas,
                                  lambdas_target,
                                  Th_hat,
                                  beta,
                                  min_ratio,
                                  float_type,
                                  num_opt_iter,
                                  "",
                                  1,
                                  proj_params=proj_params,
                                  opt_params=opt_params)
# Out:
# Starting optimization
# Performing initial conformal projection
#
# First projection complete
# Iteration 0
# Getting line search direction
# Finding direction took 2.581101179122925 s
# Delta lambdas norm 3458.597187380363 in iteration 0
#
# Energy at start of iteration 0: 3590.0396461799983
#
# Line step with beta 0.0001
# Energy after line step: 3589.7064506463735
# Max stretch relative to target: 502422.83563022007
# Max stretch relative to initial: 1.0000056270004667
# Max stretch relative to previous: 1.0000056270004667
# Max angle error: 0.0156669615929399
#
# Projecting to constraint
# Projecting to constraint took 3.062516927719116 s
# Energy after projection: 3589.7128472747822
#
# Energy at end of iteration 0: 3589.7128472747822
# Max stretch relative to target: 502428.37631659687
# Max stretch relative to initial: 1.0000055131240146
# Max stretch relative to previous: 1.0000055131240146
# Max angle error: 2.922571518126915e-09
#
# Total optimization time 8.29387617111206
#
# Convergence ratio at end of iteration 0: 0.96347461051266
#
# Iteration 1
# Getting line search direction
# Finding direction took 2.4937286376953125 s
# Delta lambdas norm 3457.4829904227045 in iteration 1
#
# Energy at start of iteration 1: 3589.7128472747822
#
# Line step with beta 0.0002
# Energy after line step: 3589.0468273155175
# Max stretch relative to target: 501688.3349274877
# Max stretch relative to initial: 1.0000481736425941
# Max stretch relative to previous: 1.0000210928980526
# Max angle error: 0.0337512060914813
#
# Projecting to constraint
# Projecting to constraint took 3.1290476322174072 s
# Energy after projection: 3589.073542148283
#
# Energy at end of iteration 1: 3589.073542148283
# Max stretch relative to target: 501713.224802986
# Max stretch relative to initial: 1.0000469566756651
# Max stretch relative to previous: 1.0000202902656488
# Max angle error: 1.7892434200916796e-09
#
# Total optimization time 14.256650924682617
#
# Convergence ratio at end of iteration 1: 0.9633357884199794
#
# Iteration 2
# Getting line search direction
# Finding direction took 2.544173240661621 s
# Delta lambdas norm 3455.021476036686 in iteration 2
#
# Energy at start of iteration 2: 3589.073542148283
#
# Line step with beta 0.0004
# Energy after line step: 3587.7431711478953
# Max stretch relative to target: 500276.8598734005
# Max stretch relative to initial: 1.0002366219936847
# Max stretch relative to previous: 1.0000727575469113
# Max angle error: 0.08452394467712576
#
# Projecting to constraint
# Projecting to constraint took 3.4565460681915283 s
# Energy after projection: 3587.8634917359805
#
# Energy at end of iteration 2: 3587.8634917359805
# Max stretch relative to target: 500789.1683908577
# Max stretch relative to initial: 1.0002276951822253
# Max stretch relative to previous: 1.0000678459438532
# Max angle error: 2.269278098765426e-10
#
# Total optimization time 20.65220808982849
#
# Convergence ratio at end of iteration 2: 0.9629746181800749
#
# Iteration 3
# Getting line search direction
# Finding direction took 2.478494167327881 s
# Delta lambdas norm 3450.9596519127754 in iteration 3
#
# Energy at start of iteration 3: 3587.8634917359805
#
# Line step with beta 0.0008
# Energy after line step: 3585.208147494405
# Max stretch relative to target: 498134.3904495902
# Max stretch relative to initial: 1.0008542218371077
# Max stretch relative to previous: 1.0002010061410282
# Max angle error: 0.5727790471932206
#
# Projecting to constraint
# Projecting to constraint took 3.63187575340271 s
# Energy after projection: 3585.470645733734
#
# Energy at end of iteration 3: 3585.470645733734
# Max stretch relative to target: 498572.8447587404
# Max stretch relative to initial: 1.000816209442199
# Max stretch relative to previous: 1.0001816660525265
# Max angle error: 1.5933210306684487e-10
#
# Total optimization time 27.13790512084961
#
# Convergence ratio at end of iteration 3: 0.9624844247488095
#
# Iteration 4
# Getting line search direction
# Finding direction took 2.5547688007354736 s
# Delta lambdas norm 3446.8614431608 in iteration 4
#
# Energy at start of iteration 4: 3585.470645733734
#
# Line step with beta 0.0016
# Energy after line step: 3580.1691905884704
# Max stretch relative to target: 492696.48672785045
# Max stretch relative to initial: 1.0026169756958514
# Max stretch relative to previous: 1.0008100587065611
# Max angle error: 0.906562938555096
#
# Projecting to constraint
# Projecting to constraint took 3.795621871948242 s
# Energy after projection: 3580.6898194396517
#
# Energy at end of iteration 4: 3580.6898194396517
# Max stretch relative to target: 496335.52976355446
# Max stretch relative to initial: 1.0020308123554753
# Max stretch relative to previous: 1.0004829714574155
# Max angle error: 1.2245582325931537e-10
#
# Total optimization time 33.84449815750122
#
# Convergence ratio at end of iteration 4: 0.9626249736706334
#
# Iteration 5
# Getting line search direction
# Finding direction took 2.7628390789031982 s
# Delta lambdas norm 3439.6842417791418 in iteration 5
#
# Energy at start of iteration 5: 3580.6898194396517
#
# Line step with beta 0.0032
# Energy after line step: 3570.1175889290207
# Max stretch relative to target: 485392.93580905383
# Max stretch relative to initial: 1.0101567267919913
# Max stretch relative to previous: 1.0032680441448805
# Max angle error: 0.2577421364275745
#
# Projecting to constraint
# Projecting to constraint took 3.5633463859558105 s
# Energy after projection: 3570.4260400833464
#
# Energy at end of iteration 5: 3570.4260400833464
# Max stretch relative to target: 486981.743022336
# Max stretch relative to initial: 1.0090892442989807
# Max stretch relative to previous: 1.0026762789772774
# Max angle error: 2.3800872384072136e-10
#
# Total optimization time 40.51592493057251
#
# Convergence ratio at end of iteration 5: 0.9633820174857473
#
# Iteration 6
# Getting line search direction
# Finding direction took 2.68428897857666 s
# Delta lambdas norm 3429.3611861645713 in iteration 6
#
# Energy at start of iteration 6: 3570.4260400833464
#
# Line step with beta 0.0064
# Energy after line step: 3549.3505308966724
# Max stretch relative to target: 466259.83326750307
# Max stretch relative to initial: 1.0128089085611753
# Max stretch relative to previous: 1.0051984849895428
# Max angle error: 1.681640718856416
#
# Projecting to constraint
# Projecting to constraint took 4.274927139282227 s
# Energy after projection: 3552.8783506461714
#
# Energy at end of iteration 6: 3552.8783506461714
# Max stretch relative to target: 478910.9058098915
# Max stretch relative to initial: 1.0119611023726212
# Max stretch relative to previous: 1.0049763931315172
# Max angle error: 1.566498042393505e-10
#
# Total optimization time 47.81580209732056
#
# Convergence ratio at end of iteration 6: 0.965234620414421
#
# Iteration 7
# Getting line search direction
# Finding direction took 2.8519461154937744 s
# Delta lambdas norm 3416.380755431563 in iteration 7
#
# Energy at start of iteration 7: 3552.8783506461714
#
# Line step with beta 0.0128
# Energy after line step: 3510.849245844075
# Max stretch relative to target: 431333.10530276323
# Max stretch relative to initial: 1.1307145190058039
# Max stretch relative to previous: 1.1655469546245536
# Max angle error: 3.623028535753548
#
# Projecting to constraint
# Projecting to constraint took 4.356550216674805 s
# Energy after projection: 3544.4165877402706
#
# Energy at end of iteration 7: 3544.4165877402706
# Max stretch relative to target: 524035.8538510413
# Max stretch relative to initial: 1.0404994111492802
# Max stretch relative to previous: 1.0655385116815783
# Max angle error: 7.66684937758555e-09
#
# Total optimization time 55.36707019805908
#
# Convergence ratio at end of iteration 7: 0.9638767540047158
#
# Iteration 8
# Getting line search direction
# Finding direction took 2.7442538738250732 s
# Delta lambdas norm 3413.989880263022 in iteration 8
#
# Energy at start of iteration 8: 3544.4165877402706
#
# Line step with beta 0.0256
# Energy after line step: 3460.3142394155143
# Max stretch relative to target: 422773.29117203073
# Max stretch relative to initial: 1.1249051662301093
# Max stretch relative to previous: 1.1895455973812918
# Max angle error: 6.575262943717904
#
# Projecting to constraint
# Projecting to constraint took 8.49164080619812 s
# Energy after projection: 3552.5048834336626
#
# Line step with beta 0.0128
# Energy after line step: 3502.345240366141
# Max stretch relative to target: 470689.24209582125
# Max stretch relative to initial: 1.0359455769322308
# Max stretch relative to previous: 1.0463139102060364
# Max angle error: 4.215022466370014
#
# Projecting to constraint
# Projecting to constraint took 3.7542169094085693 s
# Energy after projection: 3531.542848400412
#
# Energy at end of iteration 8: 3531.542848400412
# Max stretch relative to target: 574605.9214890917
# Max stretch relative to initial: 1.0596423418045244
# Max stretch relative to previous: 1.0503257984886778
# Max angle error: 4.641310447084379e-09
#
# Total optimization time 70.97653913497925
#
# Convergence ratio at end of iteration 8: 0.9667134243633388
#
# Iteration 9
# Getting line search direction
# Finding direction took 2.6317148208618164 s
# Delta lambdas norm 3416.89426672117 in iteration 9
#
# Energy at start of iteration 9: 3531.542848400412
#
# Line step with beta 0.0256
# Energy after line step: 3446.980969707366
# Max stretch relative to target: 440373.34513860865
# Max stretch relative to initial: 1.3127293973614536
# Max stretch relative to previous: 1.2879259551284783
# Max angle error: 10.395206773269845
#
# Projecting to constraint
# Projecting to constraint took 10.646097898483276 s
# Energy after projection: 3725.557611730359
#
# Line step with beta 0.0128
# Energy after line step: 3489.2439709109667
# Max stretch relative to target: 503031.9391277121
# Max stretch relative to initial: 1.0813654506929857
# Max stretch relative to previous: 1.0695620494222107
# Max angle error: 9.507080672283315
#
# Projecting to constraint
# Projecting to constraint took 6.961727142333984 s
# Energy after projection: 3565.7273350383716
#
# Line step with beta 0.0064
# Energy after line step: 3510.3890061496522
# Max stretch relative to target: 537629.176032067
# Max stretch relative to initial: 1.0405955387958985
# Max stretch relative to previous: 1.0172418712927154
# Max angle error: 6.887818990833431
#
# Projecting to constraint
# Projecting to constraint took 4.154091119766235 s
# Energy after projection: 3529.767185097771
#
# Energy at end of iteration 9: 3529.767185097771
# Max stretch relative to target: 568790.7690992331
# Max stretch relative to initial: 1.0573473111203238
# Max stretch relative to previous: 1.007301033718519
# Max angle error: 8.148859365064709e-11
#
# Total optimization time 96.13089299201965
#
# Convergence ratio at end of iteration 9: 0.9680225599996691
#
# Iteration 10
# Getting line search direction
# Finding direction took 2.636500835418701 s
# Delta lambdas norm 3399.276204026334 in iteration 10
#
# Energy at start of iteration 10: 3529.767185097771
#
# Line step with beta 0.0128
# Energy after line step: 3487.8846815485335
# Max stretch relative to target: 516259.3318780116
# Max stretch relative to initial: 1.0709151607819587
# Max stretch relative to previous: 1.0629663911289344
# Max angle error: 3.28075884871577
#
# Projecting to constraint
# Projecting to constraint took 5.121392726898193 s
# Energy after projection: 3570.6472798522404
#
# Line step with beta 0.0064
# Energy after line step: 3508.8209800961586
# Max stretch relative to target: 541888.8653898953
# Max stretch relative to initial: 1.0474508811467436
# Max stretch relative to previous: 1.015619611648213
# Max angle error: 1.1184392917266752
#
# Projecting to constraint
# Projecting to constraint took 3.5406110286712646 s
# Energy after projection: 3530.213823504425
#
# Line step with beta 0.0032
# Energy after line step: 3519.2928553435277
# Max stretch relative to target: 555176.8947924873
# Max stretch relative to initial: 1.0472652173676786
# Max stretch relative to previous: 1.0038973084056488
# Max angle error: 0.47847114718800476
#
# Projecting to constraint
# Projecting to constraint took 3.9364962577819824 s
# Energy after projection: 3524.1870229621277
#
# Energy at end of iteration 10: 3524.1870229621277
# Max stretch relative to target: 562625.5225837387
# Max stretch relative to initial: 1.0526106982805765
# Max stretch relative to previous: 1.0024565533398535
# Max angle error: 8.43840552988695e-11
#
# Total optimization time 112.15048599243164
#
# Convergence ratio at end of iteration 10: 0.9645561322024265
#
# Iteration 11
# Getting line search direction
# Finding direction took 2.689826011657715 s
# Delta lambdas norm 3385.4116691254676 in iteration 11
#
# Energy at start of iteration 11: 3524.1870229621277
#
# Line step with beta 0.0064
# Energy after line step: 3503.3787488631056
# Max stretch relative to target: 536535.3819168431
# Max stretch relative to initial: 1.0560762224011664
# Max stretch relative to previous: 1.0159409521470342
# Max angle error: 3.3236914159916893
#
# Projecting to constraint
# Projecting to constraint took 4.444812059402466 s
# Energy after projection: 3510.758806316138
#
# Energy at end of iteration 11: 3510.758806316138
# Max stretch relative to target: 559547.7942558962
# Max stretch relative to initial: 1.0533557497934238
# Max stretch relative to previous: 1.0104798405502518
# Max angle error: 1.7639578686612367e-10
#
# Total optimization time 119.62652897834778
#
# Convergence ratio at end of iteration 11: 0.9642962834800384
#
# Iteration 12
# Getting line search direction
# Finding direction took 2.708993911743164 s
# Delta lambdas norm 3380.072041529159 in iteration 12
#
# Energy at start of iteration 12: 3510.758806316138
#
# Line step with beta 0.0128
# Energy after line step: 3469.124116509305
# Max stretch relative to target: 505233.02881572896
# Max stretch relative to initial: 1.1580453836033207
# Max stretch relative to previous: 1.0756504558552096
# Max angle error: 2.216478668962898
#
# Projecting to constraint
# Projecting to constraint took 4.906876802444458 s
# Energy after projection: 3525.1752533577287
#
# Line step with beta 0.0064
# Energy after line step: 3489.9365040878083
# Max stretch relative to target: 531697.3075529573
# Max stretch relative to initial: 1.0705308339411737
# Max stretch relative to previous: 1.0187370749745024
# Max angle error: 1.4102371281748738
#
# Projecting to constraint
# Projecting to constraint took 4.204432010650635 s
# Energy after projection: 3512.556193088516
#
# Line step with beta 0.0032
# Energy after line step: 3500.3464269272736
# Max stretch relative to target: 545444.8236559363
# Max stretch relative to initial: 1.0582968864596554
# Max stretch relative to previous: 1.0046733486498243
# Max angle error: 0.8613063212011074
#
# Projecting to constraint
# Projecting to constraint took 3.6808037757873535 s
# Energy after projection: 3506.7564127113787
#
# Energy at end of iteration 12: 3506.7564127113787
# Max stretch relative to target: 552139.7829962607
# Max stretch relative to initial: 1.0536128955795663
# Max stretch relative to previous: 1.005956075609798
# Max angle error: 8.465752543429517e-10
#
# Total optimization time 135.9341320991516
#
# Convergence ratio at end of iteration 12: 0.9638742027467289
#
# Iteration 13
# Getting line search direction
# Finding direction took 2.7104239463806152 s
# Delta lambdas norm 3370.0057069698646 in iteration 13
#
# Energy at start of iteration 13: 3506.7564127113787
#
# Line step with beta 0.0064
# Energy after line step: 3486.0345536551554
# Max stretch relative to target: 524617.6320229976
# Max stretch relative to initial: 1.0736980267922185
# Max stretch relative to previous: 1.0277258432245542
# Max angle error: 1.5150875257734988
#
# Projecting to constraint
# Projecting to constraint took 3.897958278656006 s
# Energy after projection: 3506.810243440345
#
# Line step with beta 0.0032
# Energy after line step: 3496.394203838457
# Max stretch relative to target: 538202.8107518479
# Max stretch relative to initial: 1.0611611643938188
# Max stretch relative to previous: 1.0069076033143642
# Max angle error: 1.0972921245064837
#
# Projecting to constraint
# Projecting to constraint took 4.425537109375 s
# Energy after projection: 3503.6564105173957
#
# Energy at end of iteration 13: 3503.6564105173957
# Max stretch relative to target: 547474.4168360572
# Max stretch relative to initial: 1.0562005298004675
# Max stretch relative to previous: 1.0048194306341958
# Max angle error: 9.225864516793081e-11
#
# Total optimization time 147.54014897346497
#
# Convergence ratio at end of iteration 13: 0.9618539354640102
#
# Iteration 14
# Getting line search direction
# Finding direction took 2.681118965148926 s
# Delta lambdas norm 3367.6799728053 in iteration 14
#
# Energy at start of iteration 14: 3503.6564105173957
#
# Line step with beta 0.0064
# Energy after line step: 3482.9448094432996
# Max stretch relative to target: 519848.35571341135
# Max stretch relative to initial: 1.0757482130735503
# Max stretch relative to previous: 1.014842892242811
# Max angle error: 1.5612567188588287
#
# Projecting to constraint
# Projecting to constraint took 3.981614828109741 s
# Energy after projection: 3505.5104221662746
#
# Line step with beta 0.0032
# Energy after line step: 3493.299337260611
# Max stretch relative to target: 533482.5914567244
# Max stretch relative to initial: 1.063034031893374
# Max stretch relative to previous: 1.0037038637573361
# Max angle error: 0.8883267718724452
#
# Projecting to constraint
# Projecting to constraint took 3.7938649654388428 s
# Energy after projection: 3501.4084168019563
#
# Energy at end of iteration 14: 3501.4084168019563
# Max stretch relative to target: 544481.4087443663
# Max stretch relative to initial: 1.0624095311678419
# Max stretch relative to previous: 1.0061114240751667
# Max angle error: 2.2458301884853427e-10
#
# Total optimization time 158.54689192771912
#
# Convergence ratio at end of iteration 14: 0.9618072420929409
#
# Iteration 15
# Getting line search direction
# Finding direction took 2.61004376411438 s
# Delta lambdas norm 3363.390761262376 in iteration 15
#
# Energy at start of iteration 15: 3501.4084168019563
#
# Line step with beta 0.0064
# Energy after line step: 3480.736354966191
# Max stretch relative to target: 517411.2015491535
# Max stretch relative to initial: 1.0771836554501122
# Max stretch relative to previous: 1.0287561963929501
# Max angle error: 1.2763584525746001
#
# Projecting to constraint
# Projecting to constraint took 4.267493963241577 s
# Energy after projection: 3497.959416719252
#
# Energy at end of iteration 15: 3497.959416719252
# Max stretch relative to target: 542503.3545512782
# Max stretch relative to initial: 1.0750179437868854
# Max stretch relative to previous: 1.0127037053052816
# Max angle error: 1.857447529118872e-10
#
# Total optimization time 165.77255582809448
#
# Convergence ratio at end of iteration 15: 0.9615293834417643
#
# Iteration 16
# Getting line search direction
# Finding direction took 2.849327802658081 s
# Delta lambdas norm 3363.8143556692557 in iteration 16
#
# Energy at start of iteration 16: 3497.959416719252
#
# Line step with beta 0.0128
# Energy after line step: 3456.573975210083
# Max stretch relative to target: 493565.5455273765
# Max stretch relative to initial: 1.1087812886453294
# Max stretch relative to previous: 1.0789867656825471
# Max angle error: 6.542232602581599
#
# Projecting to constraint
# Projecting to constraint took 4.792609930038452 s
# Energy after projection: 3504.073577811662
#
# Line step with beta 0.0064
# Energy after line step: 3477.2616224608905
# Max stretch relative to target: 517456.2436955721
# Max stretch relative to initial: 1.0910836260973937
# Max stretch relative to previous: 1.0195554829636657
# Max angle error: 4.154758492543948
#
# Projecting to constraint
# Projecting to constraint took 4.623224258422852 s
# Energy after projection: 3492.242016037928
#
# Energy at end of iteration 16: 3492.242016037928
# Max stretch relative to target: 537455.1784973883
# Max stretch relative to initial: 1.0899884866273633
# Max stretch relative to previous: 1.028408546391379
# Max angle error: 1.23357324355311e-10
#
# Total optimization time 178.60245203971863
#
# Convergence ratio at end of iteration 16: 0.9632248682139224
#
# Iteration 17
# Getting line search direction
# Finding direction took 2.747649908065796 s
# Delta lambdas norm 3361.218397355611 in iteration 17
#
# Energy at start of iteration 17: 3492.242016037928
#
# Line step with beta 0.0128
# Energy after line step: 3450.8523472069437
# Max stretch relative to target: 481784.0215334343
# Max stretch relative to initial: 1.126610822621224
# Max stretch relative to previous: 1.077324343944467
# Max angle error: 2.9153345885687223
#
# Projecting to constraint
# Projecting to constraint took 5.537238836288452 s
# Energy after projection: 3502.9519739005564
#
# Line step with beta 0.0064
# Energy after line step: 3471.542215350408
# Max stretch relative to target: 508858.8382748583
# Max stretch relative to initial: 1.1074802749578263
# Max stretch relative to previous: 1.0191477674862628
# Max angle error: 2.007683163391807
#
# Projecting to constraint
# Projecting to constraint took 4.38441014289856 s
# Energy after projection: 3485.4066656346595
#
# Energy at end of iteration 17: 3485.4066656346595
# Max stretch relative to target: 540554.8499755296
# Max stretch relative to initial: 1.1042430573258801
# Max stretch relative to previous: 1.009933735048791
# Max angle error: 1.2568079910124652e-10
#
# Total optimization time 191.8836169242859
#
# Convergence ratio at end of iteration 17: 0.9643690736281889
#
# Iteration 18
# Getting line search direction
# Finding direction took 2.6624631881713867 s
# Delta lambdas norm 3357.0361178097673 in iteration 18
#
# Energy at start of iteration 18: 3485.4066656346595
#
# Line step with beta 0.0128
# Energy after line step: 3444.038609824494
# Max stretch relative to target: 485664.06420804147
# Max stretch relative to initial: 1.1432525279996506
# Max stretch relative to previous: 1.0519376880670879
# Max angle error: 4.540088993685027
#
# Projecting to constraint
# Projecting to constraint took 4.820535898208618 s
# Energy after projection: 3498.9090073978814
#
# Line step with beta 0.0064
# Energy after line step: 3464.717763230143
# Max stretch relative to target: 512374.9265591369
# Max stretch relative to initial: 1.122929606014959
# Max stretch relative to previous: 1.0129012015164873
# Max angle error: 3.315734829476062
#
# Projecting to constraint
# Projecting to constraint took 4.601357936859131 s
# Energy after projection: 3484.1033420078743
#
# Energy at end of iteration 18: 3484.1033420078743
# Max stretch relative to target: 561731.5471658453
# Max stretch relative to initial: 1.1195888368011992
# Max stretch relative to previous: 1.036523316196159
# Max angle error: 3.269198245448024e-10
#
# Total optimization time 204.52198600769043
#
# Convergence ratio at end of iteration 18: 0.9635294330492279
#
# Iteration 19
# Getting line search direction
# Finding direction took 2.569490909576416 s
# Delta lambdas norm 3354.31870407659 in iteration 19
#
# Energy at start of iteration 19: 3484.1033420078743
#
# Line step with beta 0.0128
# Energy after line step: 3442.786998540234
# Max stretch relative to target: 502422.62452121894
# Max stretch relative to initial: 1.1611429697622613
# Max stretch relative to previous: 1.0906775810432747
# Max angle error: 7.699160082678625
#
# Projecting to constraint
# Projecting to constraint took 5.032845973968506 s
# Energy after projection: 3493.821473083533
#
# Line step with beta 0.0064
# Energy after line step: 3463.4402474995163
# Max stretch relative to target: 531250.0712502783
# Max stretch relative to initial: 1.1395423625695411
# Max stretch relative to previous: 1.0224181094452687
# Max angle error: 1.806301498344368
#
# Projecting to constraint
# Projecting to constraint took 4.7230401039123535 s
# Energy after projection: 3476.292905107772
#
# Energy at end of iteration 19: 3476.292905107772
# Max stretch relative to target: 563643.5615269551
# Max stretch relative to initial: 1.1365958758634367
# Max stretch relative to previous: 1.0106700817413512
# Max angle error: 3.4224179046304926e-10
#
# Total optimization time 217.4170310497284
#
# Convergence ratio at end of iteration 19: 0.9649125650914043
#
# Iteration 20
# Getting line search direction
# Finding direction took 2.5521979331970215 s
# Delta lambdas norm 3348.895314241889 in iteration 20
#
# Energy at start of iteration 20: 3476.292905107772
#
# Line step with beta 0.0128
# Energy after line step: 3435.0172180120194
# Max stretch relative to target: 505855.20428831066
# Max stretch relative to initial: 1.180487718253581
# Max stretch relative to previous: 1.0541041533876396
# Max angle error: 6.68866688823539
#
# Projecting to constraint
# Projecting to constraint took 7.226190090179443 s
# Energy after projection: 3502.2578284341603
#
# Line step with beta 0.0064
# Energy after line step: 3455.65022167782
# Max stretch relative to target: 533968.1909645986
# Max stretch relative to initial: 1.1577228830384116
# Max stretch relative to previous: 1.0134357782779428
# Max angle error: 2.4302164173259158
#
# Projecting to constraint
# Projecting to constraint took 4.235375165939331 s
# Energy after projection: 3477.8197475550824
#
# Line step with beta 0.0032
# Energy after line step: 3465.9703642299205
# Max stretch relative to target: 548605.2614561681
# Max stretch relative to initial: 1.1469565727606628
# Max stretch relative to previous: 1.0033533221846487
# Max angle error: 1.6731405707732927
#
# Projecting to constraint
# Projecting to constraint took 4.072677135467529 s
# Energy after projection: 3471.782514701016
#
# Energy at end of iteration 20: 3471.782514701016
# Max stretch relative to target: 561170.3103595315
# Max stretch relative to initial: 1.1460203603087964
# Max stretch relative to previous: 1.0050035345662633
# Max angle error: 2.5139179626876285e-10
#
# Total optimization time 236.28536200523376
#
# Convergence ratio at end of iteration 20: 0.9646040038686842
#
# Iteration 21
# Getting line search direction
# Finding direction took 2.752283811569214 s
# Delta lambdas norm 3333.1231031870384 in iteration 21
#
# Energy at start of iteration 21: 3471.782514701016
#
# Line step with beta 0.0064
# Energy after line step: 3451.3076651395354
# Max stretch relative to target: 533219.90631117
# Max stretch relative to initial: 1.1678585296299444
# Max stretch relative to previous: 1.0312932339658727
# Max angle error: 6.281394551875535
#
# Projecting to constraint
# Projecting to constraint took 4.442539930343628 s
# Energy after projection: 3468.992370911006
#
# Energy at end of iteration 21: 3468.992370911006
# Max stretch relative to target: 567099.3819257136
# Max stretch relative to initial: 1.1658175933630204
# Max stretch relative to previous: 1.011792302684876
# Max angle error: 4.452179069858175e-09
#
# Total optimization time 243.81784319877625
#
# Convergence ratio at end of iteration 21: 0.9608332180654849
#
# Iteration 22
# Getting line search direction
# Finding direction took 2.484323024749756 s
# Delta lambdas norm 3336.5802509774862 in iteration 22
#
# Energy at start of iteration 22: 3468.992370911006
#
# Line step with beta 0.0128
# Energy after line step: 3427.93424737079
# Max stretch relative to target: 511206.2274272334
# Max stretch relative to initial: 1.2137038342563518
# Max stretch relative to previous: 1.0891826843373327
# Max angle error: 6.831612617068519
#
# Projecting to constraint
# Projecting to constraint took 6.1290442943573 s
# Energy after projection: 3492.47405293872
#
# Line step with beta 0.0064
# Energy after line step: 3448.458298819959
# Max stretch relative to target: 538428.0226832154
# Max stretch relative to initial: 1.1889369746687861
# Max stretch relative to previous: 1.022052514388897
# Max angle error: 3.4329234522164587
#
# Projecting to constraint
# Projecting to constraint took 4.088280916213989 s
# Energy after projection: 3468.498998346402
#
# Energy at end of iteration 22: 3468.498998346402
# Max stretch relative to target: 577497.6914423959
# Max stretch relative to initial: 1.182885544753762
# Max stretch relative to previous: 1.0217087585352067
# Max angle error: 5.6486371136088565e-11
#
# Total optimization time 257.1621401309967
#
# Convergence ratio at end of iteration 22: 0.961966618000522
#
# Iteration 23
# Getting line search direction
# Finding direction took 2.664463758468628 s
# Delta lambdas norm 3340.0876327423143 in iteration 23
#
# Energy at start of iteration 23: 3468.498998346402
#
# Line step with beta 0.0128
# Energy after line step: 3427.348068867624
# Max stretch relative to target: 514293.0513424787
# Max stretch relative to initial: 1.2331887470278717
# Max stretch relative to previous: 1.0898991586634756
# Max angle error: 15.170530484331579
#
# Projecting to constraint
# Projecting to constraint took 6.139419078826904 s
# Energy after projection: 3513.3292425832346
#
# Line step with beta 0.0064
# Energy after line step: 3447.918660002953
# Max stretch relative to target: 544979.861898716
# Max stretch relative to initial: 1.2072025156816233
# Max stretch relative to previous: 1.022227753160585
# Max angle error: 9.890877448697374
#
# Projecting to constraint
# Projecting to constraint took 5.9376280307769775 s
# Energy after projection: 3473.369868592958
#
# Line step with beta 0.0032
# Energy after line step: 3458.2076216480755
# Max stretch relative to target: 561003.2193571652
# Max stretch relative to initial: 1.1948375277225443
# Max stretch relative to previous: 1.0055415837151105
# Max angle error: 2.035440539494111
#
# Projecting to constraint
# Projecting to constraint took 3.7289369106292725 s
# Energy after projection: 3463.502641968047
#
# Energy at end of iteration 23: 3463.502641968047
# Max stretch relative to target: 570377.2961338254
# Max stretch relative to initial: 1.1930608767734416
# Max stretch relative to previous: 1.0039014140855484
# Max angle error: 5.312195128226449e-11
#
# Total optimization time 276.39408802986145
#
# Convergence ratio at end of iteration 23: 0.9643669943454684
#
# Iteration 24
# Getting line search direction
# Finding direction took 2.4680159091949463 s
# Delta lambdas norm 3321.0668745351322 in iteration 24
#
# Energy at start of iteration 24: 3463.502641968047
#
# Line step with beta 0.0064
# Energy after line step: 3443.127198787495
# Max stretch relative to target: 545011.3468255328
# Max stretch relative to initial: 1.217894273062766
# Max stretch relative to previous: 1.0079519956953282
# Max angle error: 2.9324164646825963
#
# Projecting to constraint
# Projecting to constraint took 3.4563839435577393 s
# Energy after projection: 3449.1795633946663
#
# Energy at end of iteration 24: 3449.1795633946663
# Max stretch relative to target: 565981.1699375388
# Max stretch relative to initial: 1.2146944302194123
# Max stretch relative to previous: 1.0037232674213015
# Max angle error: 8.157199360425693e-10
#
# Total optimization time 282.6539649963379
#
# Convergence ratio at end of iteration 24: 0.9628570544081949
#
# Iteration 25
# Getting line search direction
# Finding direction took 2.4539809226989746 s
# Delta lambdas norm 3310.6726969902684 in iteration 25
#
# Energy at start of iteration 25: 3449.1795633946663
#
# Line step with beta 0.0128
# Energy after line step: 3408.525379128731
# Max stretch relative to target: 508463.1491369945
# Max stretch relative to initial: 1.2688517872240292
# Max stretch relative to previous: 1.0920372007534354
# Max angle error: 3.297273312284144
#
# Projecting to constraint
# Projecting to constraint took 3.815767765045166 s
# Energy after projection: 3456.898694473872
#
# Line step with beta 0.0064
# Energy after line step: 3428.84725761767
# Max stretch relative to target: 536451.8319650688
# Max stretch relative to initial: 1.240930735683158
# Max stretch relative to previous: 1.022750507394994
# Max angle error: 2.5094054084584982
#
# Projecting to constraint
# Projecting to constraint took 3.9958548545837402 s
# Energy after projection: 3444.3660516325212
#
# Energy at end of iteration 25: 3444.3660516325212
# Max stretch relative to target: 562553.4385274227
# Max stretch relative to initial: 1.2311839348665412
# Max stretch relative to previous: 1.0098640107165056
# Max angle error: 3.8623326759079646e-11
#
# Total optimization time 293.46313095092773
#
# Convergence ratio at end of iteration 25: 0.9611849168647779
#
# Iteration 26
# Getting line search direction
# Finding direction took 2.420975923538208 s
# Delta lambdas norm 3316.1132485104213 in iteration 26
#
# Energy at start of iteration 26: 3444.3660516325212
#
# Line step with beta 0.0128
# Energy after line step: 3403.5196541437267
# Max stretch relative to target: 502105.58791894215
# Max stretch relative to initial: 1.2866682440076576
# Max stretch relative to previous: 1.0926436020145114
# Max angle error: 7.740821193642278
#
# Projecting to constraint
# Projecting to constraint took 5.4953718185424805 s
# Energy after projection: 3501.3392062093726
#
# Line step with beta 0.0064
# Energy after line step: 3423.9379880285137
# Max stretch relative to target: 531470.8129216795
# Max stretch relative to initial: 1.258095669660365
# Max stretch relative to previous: 1.0228987247070238
# Max angle error: 2.3964072220313763
#
# Projecting to constraint
# Projecting to constraint took 3.8863489627838135 s
# Energy after projection: 3457.164069440983
#
# Line step with beta 0.0032
# Energy after line step: 3434.1508144656673
# Max stretch relative to target: 546791.3068859588
# Max stretch relative to initial: 1.2444344685656832
# Max stretch relative to previous: 1.0057083883281037
# Max angle error: 1.4648404873170442
#
# Projecting to constraint
# Projecting to constraint took 3.6153640747070312 s
# Energy after projection: 3443.4374414837553
#
# Energy at end of iteration 26: 3443.4374414837553
# Max stretch relative to target: 561952.5839797221
# Max stretch relative to initial: 1.2417658486918637
# Max stretch relative to previous: 1.0066515235074178
# Max angle error: 1.8951613611761786e-09
#
# Total optimization time 309.63399600982666
#
# Convergence ratio at end of iteration 26: 0.9630241016028243
#
# Iteration 27
# Getting line search direction
# Finding direction took 2.455834150314331 s
# Delta lambdas norm 3304.8458697665906 in iteration 27
#
# Energy at start of iteration 27: 3443.4374414837553
#
# Line step with beta 0.0064
# Energy after line step: 3423.142868021843
# Max stretch relative to target: 533587.6644237548
# Max stretch relative to initial: 1.269375062423272
# Max stretch relative to previous: 1.030098789328522
# Max angle error: 1.716041173513795
#
# Projecting to constraint
# Projecting to constraint took 3.6698098182678223 s
# Energy after projection: 3444.694241564976
#
# Line step with beta 0.0032
# Energy after line step: 3433.2888624184793
# Max stretch relative to target: 547586.4925312103
# Max stretch relative to initial: 1.2553627838157606
# Max stretch relative to previous: 1.007496597842524
# Max angle error: 0.8970160116749
#
# Projecting to constraint
# Projecting to constraint took 3.5086560249328613 s
# Energy after projection: 3439.940396784896
#
# Energy at end of iteration 27: 3439.940396784896
# Max stretch relative to target: 559370.4160834305
# Max stretch relative to initial: 1.254615715454705
# Max stretch relative to previous: 1.0044023793703034
# Max angle error: 6.706954991386738e-10
#
# Total optimization time 319.81276988983154
#
# Convergence ratio at end of iteration 27: 0.9607276547161776
#
# Iteration 28
# Getting line search direction
# Finding direction took 2.473148822784424 s
# Delta lambdas norm 3303.1704621502963 in iteration 28
#
# Energy at start of iteration 28: 3439.940396784896
#
# Line step with beta 0.0064
# Energy after line step: 3419.6457237006907
# Max stretch relative to target: 528194.0004163748
# Max stretch relative to initial: 1.28294014795525
# Max stretch relative to previous: 1.0150839540322667
# Max angle error: 1.5085705395861035
#
# Projecting to constraint
# Projecting to constraint took 4.1004557609558105 s
# Energy after projection: 3442.3967178889147
#
# Line step with beta 0.0032
# Energy after line step: 3429.791783265142
# Max stretch relative to target: 543558.734439691
# Max stretch relative to initial: 1.268569145059657
# Max stretch relative to previous: 1.0037639050175762
# Max angle error: 0.9076169967907415
#
# Projecting to constraint
# Projecting to constraint took 3.5328519344329834 s
# Energy after projection: 3437.4422195400425
#
# Energy at end of iteration 28: 3437.4422195400425
# Max stretch relative to target: 562582.3831611781
# Max stretch relative to initial: 1.2672219307636112
# Max stretch relative to previous: 1.0084812186629986
# Max angle error: 3.276774407368066e-10
#
# Total optimization time 330.47482681274414
#
# Convergence ratio at end of iteration 28: 0.9609384685431271
#
# Iteration 29
# Getting line search direction
# Finding direction took 2.7457220554351807 s
# Delta lambdas norm 3298.6895018536325 in iteration 29
#
# Energy at start of iteration 29: 3437.4422195400425
#
# Line step with beta 0.0064
# Energy after line step: 3417.187937685208
# Max stretch relative to target: 534186.2690172815
# Max stretch relative to initial: 1.2962130428570355
# Max stretch relative to previous: 1.0274923868363663
# Max angle error: 4.729323528851005
#
# Projecting to constraint
# Projecting to constraint took 4.313751935958862 s
# Energy after projection: 3440.1481631776624
#
# Line step with beta 0.0032
# Energy after line step: 3427.313785170531
# Max stretch relative to target: 548200.4964205339
# Max stretch relative to initial: 1.2815078763248817
# Max stretch relative to previous: 1.0068496379391427
# Max angle error: 3.094905491455423
#
# Projecting to constraint
# Projecting to constraint took 4.1011011600494385 s
# Energy after projection: 3434.6554296530844
#
# Energy at end of iteration 29: 3434.6554296530844
# Max stretch relative to target: 557144.335464357
# Max stretch relative to initial: 1.2796988580211233
# Max stretch relative to previous: 1.0043263812746814
# Max angle error: 9.225775698951111e-11
#
# Total optimization time 342.1917049884796
#
# Convergence ratio at end of iteration 29: 0.9604135172845606
#
# Iteration 30
# Getting line search direction
# Finding direction took 2.763443946838379 s
# Delta lambdas norm 3294.612340246988 in iteration 30
#
# Energy at start of iteration 30: 3434.6554296530844
#
# Line step with beta 0.0064
# Energy after line step: 3414.434842866986
# Max stretch relative to target: 528474.699820976
# Max stretch relative to initial: 1.3093310394919637
# Max stretch relative to previous: 1.0227234237355303
# Max angle error: 1.4713488255289455
#
# Projecting to constraint
# Projecting to constraint took 3.483414888381958 s
# Energy after projection: 3434.923826542472
#
# Line step with beta 0.0032
# Energy after line step: 3424.5438321821953
# Max stretch relative to target: 542620.2036797769
# Max stretch relative to initial: 1.2943045755772775
# Max stretch relative to previous: 1.0056648108926578
# Max angle error: 1.075691818732885
#
# Projecting to constraint
# Projecting to constraint took 3.5975148677825928 s
# Energy after projection: 3431.2746121754712
#
# Energy at end of iteration 30: 3431.2746121754712
# Max stretch relative to target: 555204.8635983516
# Max stretch relative to initial: 1.2930302549474204
# Max stretch relative to previous: 1.002955037641192
# Max angle error: 9.034796022433511e-09
#
# Total optimization time 352.6220860481262
#
# Convergence ratio at end of iteration 30: 0.9601715725568705
#
# Iteration 31
# Getting line search direction
# Finding direction took 2.5006160736083984 s
# Delta lambdas norm 3293.161190290101 in iteration 31
#
# Energy at start of iteration 31: 3431.2746121754712
#
# Line step with beta 0.0064
# Energy after line step: 3411.0518631704567
# Max stretch relative to target: 525739.7287233958
# Max stretch relative to initial: 1.3233119281718313
# Max stretch relative to previous: 1.0239596787225083
# Max angle error: 1.7852462980856387
#
# Projecting to constraint
# Projecting to constraint took 3.370713949203491 s
# Energy after projection: 3433.9421141792945
#
# Line step with beta 0.0032
# Energy after line step: 3421.1619498080595
# Max stretch relative to target: 540271.463594096
# Max stretch relative to initial: 1.3079601770850655
# Max stretch relative to previous: 1.0059720867704303
# Max angle error: 1.1027514630945268
#
# Projecting to constraint
# Projecting to constraint took 3.486489772796631 s
# Energy after projection: 3428.390158321695
#
# Energy at end of iteration 31: 3428.390158321695
# Max stretch relative to target: 555961.6573290561
# Max stretch relative to initial: 1.3063731251320188
# Max stretch relative to previous: 1.0039901826667075
# Max angle error: 3.2308378195011755e-10
#
# Total optimization time 362.5466821193695
#
# Convergence ratio at end of iteration 31: 0.9605561322408553
#
# Iteration 32
# Getting line search direction
# Finding direction took 2.529755115509033 s
# Delta lambdas norm 3291.016680674038 in iteration 32
#
# Energy at start of iteration 32: 3428.390158321695
#
# Line step with beta 0.0064
# Energy after line step: 3408.176724171299
# Max stretch relative to target: 526401.4766946861
# Max stretch relative to initial: 1.3373563722929536
# Max stretch relative to previous: 1.024918106880245
# Max angle error: 4.496508885020052
#
# Projecting to constraint
# Projecting to constraint took 4.282846212387085 s
# Energy after projection: 3432.5065282566434
#
# Line step with beta 0.0032
# Energy after line step: 3418.282159672065
# Max stretch relative to target: 540979.701470988
# Max stretch relative to initial: 1.3216523938301716
# Max stretch relative to previous: 1.006210243160008
# Max angle error: 3.0270406778882837
#
# Projecting to constraint
# Projecting to constraint took 3.633246898651123 s
# Energy after projection: 3426.7577412838887
#
# Energy at end of iteration 32: 3426.7577412838887
# Max stretch relative to target: 558156.3867913076
# Max stretch relative to initial: 1.3187215875159373
# Max stretch relative to previous: 1.0047568803128069
# Max angle error: 4.188358104784129e-09
#
# Total optimization time 373.5628819465637
#
# Convergence ratio at end of iteration 32: 0.9603879028346506
#
# Iteration 33
# Getting line search direction
# Finding direction took 2.5136959552764893 s
# Delta lambdas norm 3287.905356394131 in iteration 33
#
# Energy at start of iteration 33: 3426.7577412838887
#
# Line step with beta 0.0064
# Energy after line step: 3406.5729541604987
# Max stretch relative to target: 528842.0219124232
# Max stretch relative to initial: 1.350249007950081
# Max stretch relative to previous: 1.0239414054433937
# Max angle error: 1.9143735945784979
#
# Projecting to constraint
# Projecting to constraint took 3.8908989429473877 s
# Energy after projection: 3427.6500759683872
#
# Line step with beta 0.0032
# Energy after line step: 3416.6640538747592
# Max stretch relative to target: 543301.5296629
# Max stretch relative to initial: 1.3342728538462998
# Max stretch relative to previous: 1.0059675455608381
# Max angle error: 1.1965697747292294
#
# Projecting to constraint
# Projecting to constraint took 4.0440027713775635 s
# Energy after projection: 3423.0692109177403
#
# Energy at end of iteration 33: 3423.0692109177403
# Max stretch relative to target: 558049.8208297512
# Max stretch relative to initial: 1.3330809503093413
# Max stretch relative to previous: 1.0043357693398687
# Max angle error: 8.897771408555855e-11
#
# Total optimization time 384.5848710536957
#
# Convergence ratio at end of iteration 33: 0.9605138411772366
#
# Iteration 34
# Getting line search direction
# Finding direction took 2.9093761444091797 s
# Delta lambdas norm 3283.961832831921 in iteration 34
#
# Energy at start of iteration 34: 3423.0692109177403
#
# Line step with beta 0.0064
# Energy after line step: 3402.9111308736165
# Max stretch relative to target: 528856.5459352671
# Max stretch relative to initial: 1.365319977086978
# Max stretch relative to previous: 1.0323096276178363
# Max angle error: 0.9854830947002942
#
# Projecting to constraint
# Projecting to constraint took 4.20271897315979 s
# Energy after projection: 3424.840360543042
#
# Line step with beta 0.0032
# Energy after line step: 3412.9888750723767
# Max stretch relative to target: 543257.1220921235
# Max stretch relative to initial: 1.348986688313968
# Max stretch relative to previous: 1.0080450455257037
# Max angle error: 0.6803371002854135
#
# Projecting to constraint
# Projecting to constraint took 3.7936930656433105 s
# Energy after projection: 3420.157572048482
#
# Energy at end of iteration 34: 3420.157572048482
# Max stretch relative to target: 558234.6285519922
# Max stretch relative to initial: 1.3469599445779274
# Max stretch relative to previous: 1.0045544187047062
# Max angle error: 6.536460261941102e-11
#
# Total optimization time 396.0665819644928
#
# Convergence ratio at end of iteration 34: 0.9601785191624995
#
# Iteration 35
# Getting line search direction
# Finding direction took 2.782505989074707 s
# Delta lambdas norm 3282.8780437826886 in iteration 35
#
# Energy at start of iteration 35: 3420.157572048482
#
# Line step with beta 0.0064
# Energy after line step: 3399.9955831435964
# Max stretch relative to target: 528388.4258796473
# Max stretch relative to initial: 1.3798272420587703
# Max stretch relative to previous: 1.0219438757940678
# Max angle error: 2.847491307282569
#
# Projecting to constraint
# Projecting to constraint took 4.516129016876221 s
# Energy after projection: 3425.1934945231565
#
# Line step with beta 0.0032
# Energy after line step: 3410.0752971285815
# Max stretch relative to target: 543106.5426342202
# Max stretch relative to initial: 1.3631791368061705
# Max stretch relative to previous: 1.0054710030115408
# Max angle error: 1.8435850574088182
#
# Projecting to constraint
# Projecting to constraint took 3.6276559829711914 s
# Energy after projection: 3418.7918038387243
#
# Energy at end of iteration 35: 3418.7918038387243
# Max stretch relative to target: 560854.7584132146
# Max stretch relative to initial: 1.359814760795836
# Max stretch relative to previous: 1.0058951744630278
# Max angle error: 3.934275127903675e-11
#
# Total optimization time 407.54604721069336
#
# Convergence ratio at end of iteration 35: 0.9602450901211862
#
# Iteration 36
# Getting line search direction
# Finding direction took 2.5242719650268555 s
# Delta lambdas norm 3279.9611178888786 in iteration 36
#
# Energy at start of iteration 36: 3418.7918038387243
#
# Line step with beta 0.0064
# Energy after line step: 3398.657646014635
# Max stretch relative to target: 531180.2306759151
# Max stretch relative to initial: 1.3932577095720153
# Max stretch relative to previous: 1.028142466498251
# Max angle error: 2.074090821235057
#
# Projecting to constraint
# Projecting to constraint took 3.5887420177459717 s
# Energy after projection: 3418.5455317688775
#
# Energy at end of iteration 36: 3418.5455317688775
# Max stretch relative to target: 582367.9152491951
# Max stretch relative to initial: 1.3887935580395587
# Max stretch relative to previous: 1.0232561193767187
# Max angle error: 2.8196263102131525e-09
#
# Total optimization time 414.00190901756287
#
# Convergence ratio at end of iteration 36: 0.9594610010040467
#
# Iteration 37
# Getting line search direction
# Finding direction took 2.412109851837158 s
# Delta lambdas norm 3282.554285144431 in iteration 37
#
# Energy at start of iteration 37: 3418.5455317688775
#
# Line step with beta 0.0128
# Energy after line step: 3378.220654398087
# Max stretch relative to target: 525251.5111328128
# Max stretch relative to initial: 1.4600829146535272
# Max stretch relative to previous: 1.0634280872464164
# Max angle error: 4.452414162283889
#
# Projecting to constraint
# Projecting to constraint took 3.779536008834839 s
# Energy after projection: 3413.1500077969795
#
# Energy at end of iteration 37: 3413.1500077969795
# Max stretch relative to target: 633507.2554574641
# Max stretch relative to initial: 1.4461330498796239
# Max stretch relative to previous: 1.2090967646517885
# Max angle error: 5.02868502394449e-09
#
# Total optimization time 420.52928495407104
#
# Convergence ratio at end of iteration 37: 0.961737479350683
#
# Iteration 38
# Getting line search direction
# Finding direction took 2.442363977432251 s
# Delta lambdas norm 3286.399819544006 in iteration 38
#
# Energy at start of iteration 38: 3413.1500077969795
#
# Line step with beta 0.0256
# Energy after line step: 3332.2198971433313
# Max stretch relative to target: 498636.9896429851
# Max stretch relative to initial: 1.6048821953032741
# Max stretch relative to previous: 1.3821921576600795
# Max angle error: 8.815686081755755
#
# Projecting to constraint
# Projecting to constraint took 4.982240915298462 s
# Energy after projection: 3505.600907478808
#
# Line step with beta 0.0128
# Energy after line step: 3372.665365536596
# Max stretch relative to target: 562041.0579115062
# Max stretch relative to initial: 1.5218692510750134
# Max stretch relative to previous: 1.0913734827409176
# Max angle error: 5.540730653723937
#
# Projecting to constraint
# Projecting to constraint took 6.743276119232178 s
# Energy after projection: 3438.7560943628973
#
# Line step with beta 0.0064
# Energy after line step: 3392.9028775444676
# Max stretch relative to target: 596705.193585513
# Max stretch relative to initial: 1.4831149850437066
# Max stretch relative to previous: 1.0225882560299913
# Max angle error: 3.1808732242913678
#
# Projecting to constraint
# Projecting to constraint took 3.8961021900177 s
# Energy after projection: 3412.8637675994423
#
# Energy at end of iteration 38: 3412.8637675994423
# Max stretch relative to target: 633760.6873149936
# ...
# Max angle error: 1.1485141726552683e-09
#
# Total optimization time 10553.827661037445
#
# Convergence ratio at end of iteration 320: 0.9411719763641105
#
# Iteration 321
# Getting line search direction
# Finding direction took 2.993837833404541 s
# Delta lambdas norm 2631.8126363810425 in iteration 321
#
# Energy at start of iteration 321: 2798.872792733441
#
# Line step with beta 0.0064
# Energy after line step: 2783.0404623538557
# Max stretch relative to target: 505920.3826315212
# Max stretch relative to initial: 46.72115952414736
# Max stretch relative to previous: 1.0299378297221273
# Max angle error: 2.494399110910418
#
# Projecting to constraint
# Projecting to constraint took 4.42673397064209 s
# Energy after projection: 2806.081054899165
#
# Line step with beta 0.0032
# Energy after line step: 2790.955147575564
# Max stretch relative to target: 519177.09964414936
# Max stretch relative to initial: 45.83667364024712
# Max stretch relative to previous: 1.0074566565669532
# Max angle error: 1.6823072970848854
#
# Projecting to constraint
# Projecting to constraint took 4.360040187835693 s
# Energy after projection: 2797.882339413009
#
# Energy at end of iteration 321: 2797.882339413009
# Max stretch relative to target: 533001.8913084433
# Max stretch relative to initial: 45.38697553405128
# Max stretch relative to previous: 1.0042688452178326
# Max angle error: 2.926342723696962e-09
#
# Total optimization time 10566.176088094711
#
# Convergence ratio at end of iteration 321: 0.9406445007738218
#
# Iteration 322
# Getting line search direction
# Finding direction took 2.7722361087799072 s
# Delta lambdas norm 2632.2271809246504 in iteration 322
#
# Energy at start of iteration 322: 2797.882339413009
#
# Line step with beta 0.0064
# Energy after line step: 2782.0393670541575
# Max stretch relative to target: 503116.20638637524
# Max stretch relative to initial: 47.14803809346229
# Max stretch relative to previous: 1.0135552603754425
# Max angle error: 1.232080716265906
#
# Projecting to constraint
# Projecting to constraint took 3.966384172439575 s
# Energy after projection: 2805.1502569751096
#
# Line step with beta 0.0032
# Energy after line step: 2789.9593838353726
# Max stretch relative to target: 517843.4990920192
# Max stretch relative to initial: 46.259123304868545
# Max stretch relative to previous: 1.0033830924366431
# Max angle error: 0.6382890333576059
#
# Projecting to constraint
# Projecting to constraint took 4.558196067810059 s
# Energy after projection: 2796.757417399625
#
# Energy at end of iteration 322: 2796.757417399625
# Max stretch relative to target: 533400.5802900181
# Max stretch relative to initial: 45.79384775145132
# Max stretch relative to previous: 1.0046747903972062
# Max angle error: 7.44719841350161e-11
#
# Total optimization time 10578.068645954132
#
# Convergence ratio at end of iteration 322: 0.9411710735255859
#
# Iteration 323
# Getting line search direction
# Finding direction took 4.046217918395996 s
# Delta lambdas norm 2629.506470532381 in iteration 323
#
# Energy at start of iteration 323: 2796.757417399625
#
# Line step with beta 0.0064
# Energy after line step: 2780.9408774174253
# Max stretch relative to target: 506489.7843678092
# Max stretch relative to initial: 47.57320415638621
# Max stretch relative to previous: 1.0295641786179295
# Max angle error: 1.6436084217090006
#
# Projecting to constraint
# Projecting to constraint took 4.486021041870117 s
# Energy after projection: 2803.867279229863
#
# Line step with beta 0.0032
# Energy after line step: 2788.847666198299
# Max stretch relative to target: 519771.05045659747
# Max stretch relative to initial: 46.67504370317662
# Max stretch relative to previous: 1.0073639309152203
# Max angle error: 1.1391563261226745
#
# Projecting to constraint
# Projecting to constraint took 3.829704761505127 s
# Energy after projection: 2795.5997797001605
#
# Energy at end of iteration 323: 2795.5997797001605
# Max stretch relative to target: 533737.7966319073
# Max stretch relative to initial: 46.207658696157026
# Max stretch relative to previous: 1.004176700929702
# Max angle error: 7.815863511950738e-10
#
# Total optimization time 10591.023493051529
#
# Convergence ratio at end of iteration 323: 0.9405875939847178
#
# Iteration 324
# Getting line search direction
# Finding direction took 2.6923887729644775 s
# Delta lambdas norm 2629.6709231933423 in iteration 324
#
# Energy at start of iteration 324: 2795.5997797001605
#
# Line step with beta 0.0064
# Energy after line step: 2779.7746691756774
# Max stretch relative to target: 503859.0295347506
# Max stretch relative to initial: 47.994614128493126
# Max stretch relative to previous: 1.0134145924885143
# Max angle error: 1.3696617690068678
#
# Projecting to constraint
# Projecting to constraint took 3.76395320892334 s
# Energy after projection: 2803.045181063902
#
# Line step with beta 0.0032
# Energy after line step: 2787.685753181826
# Max stretch relative to target: 518583.2703018564
# Max stretch relative to initial: 47.092657482617554
# Max stretch relative to previous: 1.0033480434247417
# Max angle error: 1.0049947798237282
#
# Projecting to constraint
# Projecting to constraint took 4.417657852172852 s
# Energy after projection: 2794.6068395573266
#
# Energy at end of iteration 324: 2794.6068395573266
# Max stretch relative to target: 533804.5228479288
# Max stretch relative to initial: 46.612823544024714
# Max stretch relative to previous: 1.0045268963150407
# Max angle error: 1.1355716367233981e-10
#
# Total optimization time 10602.449780225754
#
# Convergence ratio at end of iteration 324: 0.9409806366930275
#
# Iteration 325
# Getting line search direction
# Finding direction took 3.220104217529297 s
# Delta lambdas norm 2627.0404011074625 in iteration 325
#
# Energy at start of iteration 325: 2794.6068395573266
#
# Line step with beta 0.0064
# Energy after line step: 2778.8078190347037
# Max stretch relative to target: 506919.41892770893
# Max stretch relative to initial: 48.41753956186112
# Max stretch relative to previous: 1.0297899677376325
# Max angle error: 2.419284443818727
#
# Projecting to constraint
# Projecting to constraint took 4.242511034011841 s
# Energy after projection: 2801.762375570969
#
# Line step with beta 0.0032
# Energy after line step: 2786.705845919139
# Max stretch relative to target: 520188.31065591454
# Max stretch relative to initial: 47.50660866749929
# Max stretch relative to previous: 1.0074199640015162
# Max angle error: 1.659599883559876
#
# Projecting to constraint
# Projecting to constraint took 4.226359128952026 s
# Energy after projection: 2793.5589315385682
#
# Energy at end of iteration 325: 2793.5589315385682
# Max stretch relative to target: 534006.6896469985
# Max stretch relative to initial: 47.034926587206044
# Max stretch relative to previous: 1.0042495829903872
# Max angle error: 1.0091927293842673e-10
#
# Total optimization time 10614.694769144058
#
# Convergence ratio at end of iteration 325: 0.940391975071242
#
# Iteration 326
# Getting line search direction
# Finding direction took 2.6397488117218018 s
# Delta lambdas norm 2627.5289189917717 in iteration 326
#
# Energy at start of iteration 326: 2793.5589315385682
#
# Line step with beta 0.0064
# Energy after line step: 2777.7480560768013
# Max stretch relative to target: 504045.76394360606
# Max stretch relative to initial: 48.84832878037177
# Max stretch relative to previous: 1.0134885427833298
# Max angle error: 1.2911408558343593
#
# Projecting to constraint
# Projecting to constraint took 3.772413730621338 s
# Energy after projection: 2801.01186902205
#
# Line step with beta 0.0032
# Energy after line step: 2785.6520219669396
# Max stretch relative to target: 518809.99396129296
# Max stretch relative to initial: 47.9330491427574
# Max stretch relative to previous: 1.003366469138602
# Max angle error: 0.629249553986563
#
# Projecting to constraint
# Projecting to constraint took 3.9745521545410156 s
# Energy after projection: 2792.5521890842538
#
# Energy at end of iteration 326: 2792.5521890842538
# Max stretch relative to target: 534355.5289155105
# Max stretch relative to initial: 47.45024210643351
# Max stretch relative to previous: 1.0046260561345342
# Max angle error: 1.2503242885486543e-10
#
# Total optimization time 10625.624732017517
#
# Convergence ratio at end of iteration 326: 0.9409059315927781
#
# Iteration 327
# Getting line search direction
# Finding direction took 2.679321050643921 s
# Delta lambdas norm 2624.7189597094957 in iteration 327
#
# Energy at start of iteration 327: 2792.5521890842538
#
# Line step with beta 0.0064
# Energy after line step: 2776.7694873697533
# Max stretch relative to target: 507431.4084727736
# Max stretch relative to initial: 49.28217419922862
# Max stretch relative to previous: 1.0293410370100362
# Max angle error: 1.4212334322245503
#
# Projecting to constraint
# Projecting to constraint took 3.7303290367126465 s
# Energy after projection: 2799.2358561035458
#
# Line step with beta 0.0032
# Energy after line step: 2784.6593530414784
# Max stretch relative to target: 520719.4817392669
# Max stretch relative to initial: 48.35753031689518
# Max stretch relative to previous: 1.007308551787891
# Max angle error: 0.9330735635870449
#
# Projecting to constraint
# Projecting to constraint took 3.798689126968384 s
# Energy after projection: 2791.1687530449817
#
# Energy at end of iteration 327: 2791.1687530449817
# Max stretch relative to target: 534620.0703279801
# Max stretch relative to initial: 47.87567626663838
# Max stretch relative to previous: 1.0041536110876765
# Max angle error: 1.7040413524682663e-10
#
# Total optimization time 10636.379540920258
#
# Convergence ratio at end of iteration 327: 0.9403655572047014
#
# Iteration 328
# Getting line search direction
# Finding direction took 2.7102248668670654 s
# Delta lambdas norm 2624.8237870105622 in iteration 328
#
# Energy at start of iteration 328: 2791.1687530449817
#
# Line step with beta 0.0064
# Energy after line step: 2775.376919289739
# Max stretch relative to target: 504689.3539557136
# Max stretch relative to initial: 49.715335932442066
# Max stretch relative to previous: 1.013362656973268
# Max angle error: 1.4670699456391585
#
# Projecting to constraint
# Projecting to constraint took 4.2322399616241455 s
# Energy after projection: 2798.444596561587
#
# Line step with beta 0.0032
# Energy after line step: 2783.271362178566
# Max stretch relative to target: 519439.176329227
# Max stretch relative to initial: 48.78683196277249
# Max stretch relative to previous: 1.0033351027880137
# Max angle error: 1.0463064017917247
#
# Projecting to constraint
# Projecting to constraint took 4.008281707763672 s
# Energy after projection: 2790.161638562699
#
# Energy at end of iteration 328: 2790.161638562699
# Max stretch relative to target: 534591.0243671769
# Max stretch relative to initial: 48.30274891572216
# Max stretch relative to previous: 1.004503901260354
# Max angle error: 2.7476687591843074e-11
#
# Total optimization time 10647.872424125671
#
# Convergence ratio at end of iteration 328: 0.9407425543857353
#
# Iteration 329
# Getting line search direction
# Finding direction took 2.676527261734009 s
# Delta lambdas norm 2622.6353812882803 in iteration 329
#
# Energy at start of iteration 329: 2790.161638562699
#
# Line step with beta 0.0064
# Energy after line step: 2774.390477806283
# Max stretch relative to target: 507678.8444426304
# Max stretch relative to initial: 50.161150744049
# Max stretch relative to previous: 1.0298294912298038
# Max angle error: 2.0489093290752596
#
# Projecting to constraint
# Projecting to constraint took 3.6881909370422363 s
# Energy after projection: 2797.6713178048844
#
# Line step with beta 0.0032
# Energy after line step: 2782.2745754848097
# Max stretch relative to target: 520961.1823352387
# Max stretch relative to initial: 49.22317658597127
# Max stretch relative to previous: 1.0074297720510854
# Max angle error: 1.4449707198219839
#
# Projecting to constraint
# Projecting to constraint took 3.729708194732666 s
# Energy after projection: 2789.3058082834946
#
# Energy at end of iteration 329: 2789.3058082834946
# Max stretch relative to target: 534869.7981467717
# Max stretch relative to initial: 48.75095402556033
# Max stretch relative to previous: 1.0042454354551955
# Max angle error: 2.6649882300944228e-09
#
# Total optimization time 10658.512100934982
#
# Convergence ratio at end of iteration 329: 0.9402466282111314
#
# Iteration 330
# Getting line search direction
# Finding direction took 2.6392529010772705 s
# Delta lambdas norm 2623.3617051654714 in iteration 330
#
# Energy at start of iteration 330: 2789.3058082834946
#
# Line step with beta 0.0064
# Energy after line step: 2773.5210176757746
# Max stretch relative to target: 504841.2258929558
# Max stretch relative to initial: 50.61841444210255
# Max stretch relative to previous: 1.0134421437556365
# Max angle error: 2.035800466318433
#
# Projecting to constraint
# Projecting to constraint took 3.949082851409912 s
# Energy after projection: 2796.755573634793
#
# Line step with beta 0.0032
# Energy after line step: 2781.411942135487
# Max stretch relative to target: 519638.64809070266
# Max stretch relative to initial: 49.67590604975713
# Max stretch relative to previous: 1.0033549082342788
# Max angle error: 1.3630636493067447
#
# Projecting to constraint
# Projecting to constraint took 4.131139039993286 s
# Energy after projection: 2788.3063555204694
#
# Energy at end of iteration 330: 2788.3063555204694
# Max stretch relative to target: 535184.0999952009
# Max stretch relative to initial: 49.195594770407524
# Max stretch relative to previous: 1.004588546625345
# Max angle error: 1.6975931771412434e-10
#
# Total optimization time 10669.776307106018
#
# Convergence ratio at end of iteration 330: 0.9408441436040808
#
# Iteration 331
# Getting line search direction
# Finding direction took 3.2633748054504395 s
# Delta lambdas norm 2619.854080208815 in iteration 331
#
# Energy at start of iteration 331: 2788.3063555204694
#
# Line step with beta 0.0064
# Energy after line step: 2772.5581929597643
# Max stretch relative to target: 508261.4995966217
# Max stretch relative to initial: 51.082851310524994
# Max stretch relative to previous: 1.0291521632707457
# Max angle error: 1.403110552683807
#
# Projecting to constraint
# Projecting to constraint took 4.041529893875122 s
# Energy after projection: 2794.1625259291973
#
# Line step with beta 0.0032
# Energy after line step: 2780.430784818346
# Max stretch relative to target: 521549.10911996436
# Max stretch relative to initial: 50.1303391004339
# Max stretch relative to previous: 1.0072616748568233
# Max angle error: 0.8896868446469997
#
# Projecting to constraint
# Projecting to constraint took 3.7752299308776855 s
# Energy after projection: 2786.676935985415
#
# Energy at end of iteration 331: 2786.676935985415
# Max stretch relative to target: 535356.1215433963
# Max stretch relative to initial: 49.64086828365445
# Max stretch relative to previous: 1.0041408702239047
# Max angle error: 1.0269207706414818e-10
#
# Total optimization time 10681.506958007812
#
# Convergence ratio at end of iteration 331: 0.9401355594463235
#
# Iteration 332
# Getting line search direction
# Finding direction took 2.8704278469085693 s
# Delta lambdas norm 2619.6833166896076 in iteration 332
#
# Energy at start of iteration 332: 2786.676935985415
#
# Line step with beta 0.0064
# Energy after line step: 2770.9215718871246
# Max stretch relative to target: 505373.0471471751
# Max stretch relative to initial: 51.53604248720351
# Max stretch relative to previous: 1.0133223902677695
# Max angle error: 1.4100788106507949
#
# Projecting to constraint
# Projecting to constraint took 4.043066024780273 s
# Energy after projection: 2793.441497588733
#
# Line step with beta 0.0032
# Energy after line step: 2778.79777549333
# Max stretch relative to target: 520148.5888217699
# Max stretch relative to initial: 50.57957637076812
# Max stretch relative to previous: 1.0033250695232752
# Max angle error: 1.024745828027119
#
# Projecting to constraint
# Projecting to constraint took 4.256993055343628 s
# Energy after projection: 2785.4846861821334
#
# Energy at end of iteration 332: 2785.4846861821334
# Max stretch relative to target: 535257.5245067971
# Max stretch relative to initial: 50.084195302960595
# Max stretch relative to previous: 1.0044948979328083
# Max angle error: 3.035971474218968e-11
#
# Total optimization time 10693.238039970398
#
# Convergence ratio at end of iteration 332: 0.9404766537346224
#
# Iteration 333
# Getting line search direction
# Finding direction took 2.8569629192352295 s

# %%
# Project to the constraint for the initial lengths
print("Performing initial conformal projection")
lambdas = project_to_constraint(C_cpp,
                                lambdas,
                                Th_hat,
                                proj_params_struct)
lambdas = np.array(lambdas)
# Out:
# Performing initial conformal projection

# %%
# Find line search direction
k = 0
delta_lambdas_k = line_search_direction(C_cpp,
                                        lambdas_target,
                                        lambdas,
                                        Th_hat)
delta_lambdas_k = np.array(delta_lambdas_k)
delta_lambdas_norm_k = norm(delta_lambdas_k)
energy_start_k = energy(lambdas, lambdas_target, p=p)
max_stretch_start_k = np.max(symmetric_stretches(lambdas, lambdas_target))
print("\nEnergy at start of iteration {}: {}\n".format(k, energy_start_k))
print("Max stretch: {}".format(max_stretch_start_k))
print("Lambdas range: [{}, {}]".format(np.min(lambdas), np.max(lambdas)))
# Out:
# Energy at start of iteration 0: 34241.96934445173
#
# Max stretch: 8940767197722.58
# Lambdas range: [-71.91895165592632, -3.837178957302624]

# %%
# Line step
beta_k = 1
lambdas_k = lambdas + beta_k * delta_lambdas_k
energy_post_step_k = energy(lambdas_k, lambdas_target, p=p)
max_stretch_post_step_k = np.max(symmetric_stretches(lambdas_k, lambdas_target))
print("Energy after line step: {}".format(energy_post_step_k))
print("Max stretch: {}".format(max_stretch_post_step_k))
print("Lambdas range: [{}, {}]".format(np.min(lambdas_k), np.max(lambdas_k)))
# Out:
# Energy after line step: 623.9214837582192
# Max stretch: 51.853310650603525
# Lambdas range: [-18.725742241793412, -1.0450957281089117]

# %%
# Make Delaunay and find angle error
F_post_step_k, _ = F_with_jacobian(C_cpp, lambdas_k, Th_hat, False)
F_post_step_k = np.array(F_post_step_k)
F_post_step_k_max = np.max(np.abs(F_post_step_k))
print("Angle error: {}".format(F_post_step_k_max))
# Out:
# Angle error: 381.88073408177746

# %%
# Project to constraint
proj_params_struct.max_itr = 100
proj_params_struct.do_reduction = True
print("Projecting to constraint")
lambdas_k = project_to_constraint(C_cpp,
                                  lambdas_k,
                                  Th_hat,
                                  proj_params_struct)
lambdas_k = np.array(lambdas_k)
# Out:
# Projecting to constraint

# %%
# Final errors
energy_end_k = energy(lambdas_k, lambdas_target, p=p)
max_stretch_end_k = np.max(symmetric_stretches(lambdas_k, lambdas_target))
print("Energy after projection: {}".format(energy_end_k))
print("Max stretch: {}".format(max_stretch_end_k))
print("Lambdas range: [{}, {}]".format(np.min(lambdas_k), np.max(lambdas_k)))
# Out:
# Energy after projection: 29502.1946143933
# Max stretch: 564663898507.1912
# Lambdas range: [-64.95277705064248, -1.914111746006158]

# %%
# Make Delaunay and find angle error
F_end_k, _ = F_with_jacobian(C_cpp, lambdas_k, Th_hat, False)
F_end_k = np.array(F_end_k)
F_end_k_max = np.max(np.abs(F_end_k))
print("Angle error: {}".format(F_end_k_max))
# Out:
# Angle error: 1.659206105841804e-11

# %% [markdown]
# ## View Energy Plots
#
# Deprecated: Requires lambdas per iteration. Should be done with logs.

# %%
print("Energy:", energy(lambdas_init, lambdas))
stretches = symmetric_stretches(lambdas, lambdas_init)
print("Max stretch:", np.max(stretches))
# Out:
# Energy: 1387.0579847946321
# Max stretch: 8112.60333038347

# %%
m_checkpoints = os.listdir(m_checkpoints_dir)
m_checkpoints = {int(f.split('_')[-1]):f for f in m_checkpoints if not f.endswith("_init")}
energies = []
max_stretches = []
for k in np.arange(len(m_checkpoints)):
    print(k)
    lambdas_k_path = os.path.join(m_checkpoints_dir, m_checkpoints[k])
    lambdas = np.loadtxt(lambdas_k_path,dtype=float)
    print("Energy:", energy(lambdas_init, lambdas))
    stretches = symmetric_stretches(lambdas, lambdas_init)
    print("Max stretch:", np.max(stretches), '\n')
    energies.append(energy(lambdas_init, lambdas))
    max_stretches.append(np.max(stretches))
# Out:
# 0
# Energy: 538.5820550055992
# Max stretch: 1017926.1535823047
#
# 1
# Energy: 370.2389074446608
# Max stretch: 11844.314479308458
#
# 2
# Energy: 331.2243259855001
# Max stretch: 5691.511701343318
#
# 3
# Energy: 319.6815007978331
# Max stretch: 10678.053804970637
#
# 4
# Energy: 294.23826842023277
# Max stretch: 3052.3182679541214
#
# 5
# Energy: 253.05917854072237
# Max stretch: 1057.3208533173565
#
# 6
# Energy: 247.1884742410975
# Max stretch: 789.1979340612471
#
# 7
# Energy: 221.60380307287153
# Max stretch: 463.66907473098627
#
# 8
# Energy: 172.32042284471
# Max stretch: 188.87741346104133
#
# 9
# Energy: 171.83999872790352
# Max stretch: 147.62297874125187
#
# 10
# Energy: 166.27478974632953
# Max stretch: 145.17559929519246
#
# 11
# Energy: 157.3526455772078
# Max stretch: 107.05132865031028
#
# 12
# Energy: 151.09879261914665
# Max stretch: 100.96814624737938
#
# 13
# Energy: 147.9849613847428
# Max stretch: 69.19815574172569
#
# 14
# Energy: 139.52477339059826
# Max stretch: 49.794440860315945
#
# 15
# Energy: 139.01552940359315
# Max stretch: 52.589108014863264
#
# 16
# Energy: 134.50265863645188
# Max stretch: 46.349564462191495
#
# 17
# Energy: 124.26110026509052
# Max stretch: 36.46998356089488
#
# 18
# Energy: 123.43952432698153
# Max stretch: 34.645694091386055
#
# 19
# Energy: 120.22095361038889
# Max stretch: 31.32485720251626
#
# 20
# Energy: 112.93561472980954
# Max stretch: 24.503726795380047
#
# 21
# Energy: 111.90228981426661
# Max stretch: 23.907119601714577
#
# 22
# Energy: 110.5606446653843
# Max stretch: 22.975714395119972
#
# 23
# Energy: 108.10217863964066
# Max stretch: 22.555815864882632
#
# 24
# Energy: 103.53380245721918
# Max stretch: 20.70654236535144
#
# 25
# Energy: 102.42162402466684
# Max stretch: 20.001368838374763
#
# 26
# Energy: 100.43629455873341
# Max stretch: 18.89426325253749
#
# 27
# Energy: 99.76655566833105
# Max stretch: 18.168962297692566
#
# 28
# Energy: 99.44252600172047
# Max stretch: 17.835781619415325
#
# 29
# Energy: 98.70176830070277
# Max stretch: 17.292976524083407
#
# 30
# Energy: 98.63531989911833
# Max stretch: 16.78965299851451
#
# 31
# Energy: 97.66851029238174
# Max stretch: 16.016616549826256
#
# 32
# Energy: 97.09060402248927
# Max stretch: 15.483085701687264
#
# 33
# Energy: 96.55827718107876
# Max stretch: 14.916898227560615
#
# 34
# Energy: 96.1811235585826
# Max stretch: 14.441672699511651
#
# 35
# Energy: 96.06902608662607
# Max stretch: 14.043154125040607
#
# 36
# Energy: 95.63793166002954
# Max stretch: 13.642130019223625
#
# 37
# Energy: 95.59500126084235
# Max stretch: 13.38891763507113
#
# 38
# Energy: 95.05535957461638
# Max stretch: 13.366527361721669
#
# 39
# Energy: 94.72181077366528
# Max stretch: 13.138646388662465
#
# 40
# Energy: 94.09303598956028
# Max stretch: 13.023540886674603
#
# 41
# Energy: 93.6382626082797
# Max stretch: 12.717467026227075
#
# 42
# Energy: 93.39191781282808
# Max stretch: 12.803709424455798
#
# 43
# Energy: 92.37225367463864
# Max stretch: 12.488989977286618
#
# 44
# Energy: 92.22345568932118
# Max stretch: 12.28931279824441
#
# 45
# Energy: 91.46899177638073
# Max stretch: 12.170784414160448
#
# 46
# Energy: 91.2513397768043
# Max stretch: 12.214904141916865
#
# 47
# Energy: 90.35017426710816
# Max stretch: 13.15703787695884
#
# 48
# Energy: 89.8002667785517
# Max stretch: 11.87340627811528
#
# 49
# Energy: 89.07706862415199
# Max stretch: 12.374311047524998

# %%
plt.plot(energies)
plt.title(m+" energy per iteration")
plt.savefig(os.path.join(output_dir, m+'_energies.png'))

# %%
plt.semilogy(max_stretches)
plt.title(m+" log max stretch per iteration")
plt.savefig(os.path.join(output_dir, m+'_max_stretches.png'))

# %%
a = np.array([1.0,2.0,3.0,4.0])

# %%
a**3
# Out:
# array([ 1.,  8., 27., 64.])

# %%
a**2
# Out:
# array([ 1.,  4.,  9., 16.])

# %%
a**1
# Out:
# array([1., 2., 3., 4.])
